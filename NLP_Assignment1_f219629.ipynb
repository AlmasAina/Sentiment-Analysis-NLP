# %% [markdown]
# # Path To file

# %%
import pandas as pd
import re


file_path = 'urdu_sarcastic_dataset.csv'
df = pd.read_csv(file_path)
df.head()
# Out:
#                                            urdu_text  is_sarcastic  \
# 0               لینے میری شادی فسادن کوجی نہیں چاہیے           1.0
# 1  چل مہمانوں میں کھانا سرو کر چڑیل چاچی نوں دسدی...           1.0
# 2  کامران خان آپکی دن بھریہ زمہ داری لگائی اپوزیش...           0.0
# 3           مراد علی شاہ بھیس میں ڈی جی ایس حامد میر           1.0
# 4                            قابل اعتبار قاتل اعتبار           1.0
#
#    Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5 Unnamed: 6  Unnamed: 7
# 0         NaN         NaN         NaN         NaN        NaN         NaN
# 1         NaN         NaN         NaN         NaN        NaN         NaN
# 2         NaN         NaN         NaN         NaN        NaN         NaN
# 3         NaN         NaN         NaN         NaN        NaN         NaN
# 4         NaN         NaN         NaN         NaN        NaN         NaN

# %% [markdown]
# # Phase 1: Text Preprocessing for Urdu Text
# 1. Stopword Removal:
# o Develop a custom list of Urdu stopwords (e.g., &quot;اور&quot;, &quot;یہ&quot;, &quot;کہ&quot;). Write a function
# to remove these stopwords from your dataset of social media posts.
# o Challenges to Address: Handle words that are often considered stopwords but
# may carry sentiment (e.g., &quot;نہیں&quot; (no), &quot;برا&quot; (bad)).

# %%
first_column = df.columns[0] 


stopwords_file_path = 'stopwords-ur.txt' 
with open(stopwords_file_path, 'r', encoding='utf-8') as f:
    urdu_stopwords = f.read().splitlines()

#function to remove stop words
def remove_stopwords(text, stopwords):
    # Tokenize the text by splitting it into words
    words = re.findall(r'\w+', text)
    words = [word for word in words if word not in stopwords]
    return ' '.join(words)

df[first_column] = df[first_column].apply(lambda x: remove_stopwords(str(x), urdu_stopwords))

print("\nCleaned Dataset (first 5 rows):")
print(df.head())

df.to_csv(file_path, index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 15
#      12     words = [word for word in words if word not in stopwords]
#      13     return ' '.join(words)
# ---> 15 df[first_column] = df[first_column].apply(lambda x: remove_stopwords(str(x), urdu_stopwords))
#      17 print("\nCleaned Dataset (first 5 rows):")
#      18 print(df.head())
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\series.py:4915, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4780 def apply(
#    4781     self,
#    4782     func: AggFuncType,
#    (...)
#    4787     **kwargs,
#    4788 ) -> DataFrame | Series:
#    4789     """
#    4790     Invoke function on values of Series.
#    4791
#    (...)
#    4906     dtype: float64
#    4907     """
#    4908     return SeriesApply(
#    4909         self,
#    4910         func,
#    4911         convert_dtype=convert_dtype,
#    4912         by_row=by_row,
#    4913         args=args,
#    4914         kwargs=kwargs,
# -> 4915     ).apply()
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[27], line 15, in <lambda>(x)
#      12     words = [word for word in words if word not in stopwords]
#      13     return ' '.join(words)
# ---> 15 df[first_column] = df[first_column].apply(lambda x: remove_stopwords(str(x), urdu_stopwords))
#      17 print("\nCleaned Dataset (first 5 rows):")
#      18 print(df.head())
#
# Cell In[27], line 12, in remove_stopwords(text, stopwords)
#       9 def remove_stopwords(text, stopwords):
#      10     # Tokenize the text by splitting it into words
#      11     words = re.findall(r'\w+', text)
# ---> 12     words = [word for word in words if word not in stopwords]
#      13     return ' '.join(words)
#
# KeyboardInterrupt:

# %% [markdown]
# # 2. Punctuation, Emojis, and Hashtags:
# o Remove unnecessary punctuation, emojis, URLs, and hashtags that don’t
# contribute to sentiment.

# %%
from IPython.display import display  

first_column = df.columns[0] 

# Function to clean text (remove punctuation, emojis, URLs, and hashtags)
def clean_text(text):
    # Remove URLs
    text = re.sub(r'http\S+|www\S+|https\S+', '', text, flags=re.MULTILINE)
    # Remove emojis (non-word characters)
    text = re.sub(r'[^\w\s]', '', text)  
    # Remove hashtags
    text = re.sub(r'#\w+', '', text)
    return text

df[first_column] = df[first_column].apply(lambda x: clean_text(str(x)))  # Clean text by removing emojis, punctuation, URLs, and hashtags

print("\nCleaned Dataset (first 5 rows):")
display(df.head()) 

df.to_csv(file_path, index=False)
# Out:
# Cleaned Dataset (first 5 rows):
#                                            urdu_text  is_sarcastic  \
# 0               لینے میری شادی فسادن کوجی نہیں چاہیے           1.0
# 1  چل مہمانوں میں کھانا سرو کر چڑیل چاچی نوں دسدی...           1.0
# 2  کامران خان آپکی دن بھریہ زمہ داری لگائی اپوزیش...           0.0
# 3           مراد علی شاہ بھیس میں ڈی جی ایس حامد میر           1.0
# 4                            قابل اعتبار قاتل اعتبار           1.0
#
#    Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5 Unnamed: 6  Unnamed: 7
# 0         NaN         NaN         NaN         NaN        NaN         NaN
# 1         NaN         NaN         NaN         NaN        NaN         NaN
# 2         NaN         NaN         NaN         NaN        NaN         NaN
# 3         NaN         NaN         NaN         NaN        NaN         NaN
# 4         NaN         NaN         NaN         NaN        NaN         NaN

# %% [markdown]
# # 3. Short Conversations:
# o Write a rule-based function to filter out very short posts or those with less than
# three words, as they may not carry sufficient sentiment.

# %%
def filter_short_posts(text):
    words = text.split()  
    if len(words) < 3:
        return None  
    return text  

df[first_column] = df[first_column].apply(lambda x: filter_short_posts(str(x)))

df = df.dropna(subset=[first_column])

print("\nFiltered Dataset (first 5 rows):")
display(df.head())  

df.to_csv(file_path, index=False)
# Out:
# Filtered Dataset (first 5 rows):
#                                            urdu_text  is_sarcastic  \
# 0               لینے میری شادی فسادن کوجی نہیں چاہیے           1.0
# 1  چل مہمانوں میں کھانا سرو کر چڑیل چاچی نوں دسدی...           1.0
# 2  کامران خان آپکی دن بھریہ زمہ داری لگائی اپوزیش...           0.0
# 3           مراد علی شاہ بھیس میں ڈی جی ایس حامد میر           1.0
# 4                            قابل اعتبار قاتل اعتبار           1.0
#
#    Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5 Unnamed: 6  Unnamed: 7
# 0         NaN         NaN         NaN         NaN        NaN         NaN
# 1         NaN         NaN         NaN         NaN        NaN         NaN
# 2         NaN         NaN         NaN         NaN        NaN         NaN
# 3         NaN         NaN         NaN         NaN        NaN         NaN
# 4         NaN         NaN         NaN         NaN        NaN         NaN

# %% [markdown]
# # Phase 2: Stemming and Lemmatization for Urdu Text
# 1. Stemming:
# o Implement or utilize a stemming algorithm for Urdu. The algorithm should reduce
# word variants to their base form (e.g., &quot;اچھا&quot;, &quot;اچھی&quot;, &quot;اچھے&quot; → &quot;اچھا&quot;).
# o Challenges to Address: Handling word inflections due to gender and plurality in
# Urdu.

# %%
first_column = df.columns[0]  

urdu_suffixes = ['ا', 'ی', 'ے', 'وں', 'یں', 'ہ']

def urdu_stemmer(word):
    for suffix in urdu_suffixes:
        if word.endswith(suffix):
            return word[:-len(suffix)]  
    return word  

def apply_stemming(text):
    words = text.split()  
    stemmed_words = [urdu_stemmer(word) for word in words]  
    return ' '.join(stemmed_words) 

df[first_column] = df[first_column].apply(lambda x: apply_stemming(str(x)))

print("\nStemmed Dataset (first 5 rows):")
print(df.head())

output_file_path = 'stem_urdu.csv'
df.to_csv(output_file_path, index=False, encoding='utf-8')
# Out:
# Stemmed Dataset (first 5 rows):
#                                            urdu_text  is_sarcastic  \
# 0                      لین میر شاد فسادن کوج نہ چاہی           1.0
# 1         چل مہمان م کھان سرو کر چڑیل چاچ ن دسد آں م           1.0
# 2  کامران خان آپک دن بھری زم دار لگائ اپوزیشن کرد...           0.0
# 3                 مراد عل شا بھیس م ڈ ج ایس حامد میر           1.0
# 4                            قابل اعتبار قاتل اعتبار           1.0
#
#    Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5 Unnamed: 6  Unnamed: 7
# 0         NaN         NaN         NaN         NaN        NaN         NaN
# 1         NaN         NaN         NaN         NaN        NaN         NaN
# 2         NaN         NaN         NaN         NaN        NaN         NaN
# 3         NaN         NaN         NaN         NaN        NaN         NaN
# 4         NaN         NaN         NaN         NaN        NaN         NaN

# %% [markdown]
# # 2. Lemmatization:
# o Implement lemmatization for Urdu, which requires using dictionaries or rules to
# return words to their dictionary form.
# o Expected Output: For example, &quot;چل رہی&quot; (is moving) should be reduced to &quot;چل&quot;
# (move).

# %%
file_path = 'urdu_sarcastic_dataset.csv'  
df = pd.read_csv(file_path, encoding='utf-8')

first_column = df.columns[0]

urdu_lemmas = {
    # Movement and Action Verbs
    "چل رہی": "چل", "چل رہے": "چل", "چلا": "چل", "چلیں": "چل", "چلی": "چل", "چلایا": "چلا", "چلاتے": "چلا",
    "کرتے": "کر", "کررہا": "کر", "کررہی": "کر", "کرچکے": "کر", "کرچکی": "کر", "کرتی": "کر", "کریں": "کر", "کیا": "کر",
    "آئے": "آ", "آرہا": "آ", "آرہی": "آ", "آچکا": "آ", "آچکی": "آ", "آئیں": "آ", "آیا": "آ",
    "گیا": "جا", "جاتا": "جا", "جارہا": "جا", "جارہی": "جا", "جائیں": "جا", "جاچکا": "جا", "جاچکی": "جا",
    "پڑھتے": "پڑھ", "پڑھتی": "پڑھ", "پڑھ رہا": "پڑھ", "پڑھ رہی": "پڑھ", "پڑھ چکے": "پڑھ", "پڑھ چکی": "پڑھ", "پڑھا": "پڑھ",
    "دیتے": "دو", "دیتی": "دو", "دے": "دو", "دے رہا": "دو", "دے رہی": "دو", "دے چکا": "دو", "دے چکی": "دو",
    "لیتے": "لے", "لیتی": "لے", "لے رہا": "لے", "لے رہی": "لے", "لے چکا": "لے", "لے چکی": "لے", "لیا": "لے",
    "کہا": "کہ", "کہتے": "کہ", "کہتی": "کہ", "کہ رہا": "کہ", "کہ رہی": "کہ", "کہ چکے": "کہ", "کہ چکی": "کہ", "کہا": "کہ",
    "دیکھا": "دیکھ", "دیکھتے": "دیکھ", "دیکھ رہی": "دیکھ", "دیکھ رہا": "دیکھ", "دیکھ چکا": "دیکھ", "دیکھ چکی": "دیکھ",
    "بنایا": "بنا", "بناتے": "بنا", "بناتی": "بنا", "بنا رہا": "بنا", "بنا رہی": "بنا", "بنا چکا": "بنا", "بنا چکی": "بنا",
    "سنا": "سن", "سنتے": "سن", "سنتی": "سن", "سن رہا": "سن", "سن رہی": "سن", "سن چکا": "سن", "سن چکی": "سن",
    "بول": "بول", "بولتا": "بول", "بولتی": "بول", "بول رہے": "بول", "بول رہی": "بول", "بول چکا": "بول", "بول چکی": "بول",
    "کھایا": "کھا", "کھاتے": "کھا", "کھاتی": "کھا", "کھا رہا": "کھا", "کھا رہی": "کھا", "کھا چکا": "کھا", "کھا چکی": "کھا",
    "لکھا": "لکھ", "لکھتے": "لکھ", "لکھتی": "لکھ", "لکھ رہا": "لکھ", "لکھ رہی": "لکھ", "لکھ چکا": "لکھ", "لکھ چکی": "لکھ",
    "سویا": "سو", "سوتے": "سو", "سوتی": "سو", "سو رہا": "سو", "سو رہی": "سو", "سو چکا": "سو", "سو چکی": "سو",
    "بیٹھا": "بیٹھ", "بیٹھتے": "بیٹھ", "بیٹھ رہی": "بیٹھ", "بیٹھ رہا": "بیٹھ", "بیٹھ چکا": "بیٹھ", "بیٹھ چکی": "بیٹھ",
    "چکھا": "چکھ", "چکھتے": "چکھ", "چکھتی": "چکھ", "چکھ رہا": "چکھ", "چکھ رہی": "چکھ", "چکھ چکا": "چکھ", "چکھ چکی": "چکھ",
    "پکایا": "پکا", "پکاتے": "پکا", "پکاتی": "پکا", "پکا رہا": "پکا", "پکا رہی": "پکا", "پکا چکا": "پکا", "پکا چکی": "پکا",
    "گایا": "گا", "گاتے": "گا", "گاتی": "گا", "گا رہا": "گا", "گا رہی": "گا", "گا چکا": "گا", "گا چکی": "گا",
    # Social Interactions
    "ملا": "مل", "ملتی": "مل", "ملتے": "مل", "مل رہا": "مل", "مل رہی": "مل", "مل چکا": "مل", "مل چکی": "مل",
    "لگتا": "لگ", "لگ رہی": "لگ", "لگ رہا": "لگ", "لگتی": "لگ", "لگ چکا": "لگ", "لگ چکی": "لگ",
    "رکھا": "رکھ", "رکھتی": "رکھ", "رکھتے": "رکھ", "رکھ رہی": "رکھ", "رکھ رہا": "رکھ", "رکھ چکا": "رکھ", "رکھ چکی": "رکھ",
    # Communication
    "پوچھا": "پوچھ", "پوچھتے": "پوچھ", "پوچھتی": "پوچھ", "پوچھ رہی": "پوچھ", "پوچھ رہا": "پوچھ", "پوچھ چکی": "پوچھ", "پوچھ چکا": "پوچھ",
    "بتایا": "بتا", "بتاتے": "بتا", "بتاتی": "بتا", "بتا رہی": "بتا", "بتا رہا": "بتا", "بتا چکی": "بتا", "بتا چکا": "بتا",
    "دکھایا": "دکھا", "دکھاتے": "دکھا", "دکھاتی": "دکھا", "دکھا رہی": "دکھا", "دکھا رہا": "دکھا", "دکھا چکی": "دکھا", "دکھا چکا": "دکھا",
    # Emotions
    "رویا": "رو", "روتے": "رو", "روتی": "رو", "رو رہا": "رو", "رو رہی": "رو", "رو چکی": "رو", "رو چکا": "رو",
    "ہنسا": "ہنس", "ہنستے": "ہنس", "ہنستی": "ہنس", "ہنس رہا": "ہنس", "ہنس رہی": "ہنس", "ہنس چکا": "ہنس", "ہنس چکی": "ہنس",
    "چاہا": "چاہ", "چاہتے": "چاہ", "چاہتی": "چاہ", "چاہ رہی": "چاہ", "چاہ رہا": "چاہ", "چاہ چکی": "چاہ", "چاہ چکا": "چاہ",
    # Perception
    "سمجھا": "سمجھ", "سمجھتی": "سمجھ", "سمجھتے": "سمجھ", "سمجھ رہی": "سمجھ", "سمجھ رہا": "سمجھ", "سمجھ چکا": "سمجھ", "سمجھ چکی": "سمجھ",
    "سیکھا": "سیکھ", "سیکھتے": "سیکھ", "سیکھتی": "سیکھ", "سیکھ رہا": "سیکھ", "سیکھ رہی": "سیکھ", "سیکھ چکا": "سیکھ", "سیکھ چکی": "سیکھ",
}

# Function to perform dictionary-based lemmatization
def urdu_lemmatizer(word):
    # Check the dictionary for known lemmatizations
    return urdu_lemmas.get(word, word)  # Return the base form if found, else return the word as-is

# Apply lemmatization to each word

# Apply lemmatization to each word in the text
def apply_lemmatization(text):
    words = text.split()  # Split the text into words
    lemmatized_words = [urdu_lemmatizer(word) for word in words]  # Apply lemmatization to each word
    return ' '.join(lemmatized_words)  # Join the lemmatized words back into a sentence

# Apply the lemmatization function to the dataset
df[first_column] = df[first_column].apply(lambda x: apply_lemmatization(str(x)))

# Display the updated dataset (first 5 rows)
print("\nLemmatized Dataset (first 5 rows):")
print(df.head())

# Save the lemmatized dataset to a new CSV file
output_file_path = 'lemmatized_urdu.csv'
df.to_csv(output_file_path, index=False, encoding='utf-8')
# Out:
# Lemmatized Dataset (first 5 rows):
#                                            urdu_text  is_sarcastic  \
# 0               لینے میری شادی فسادن کوجی نہیں چاہیے           1.0
# 1  چل مہمانوں میں کھانا سرو کر چڑیل چاچی نوں دسدی...           1.0
# 2  کامران خان آپکی دن بھریہ زمہ داری لگائی اپوزیش...           0.0
# 3           مراد علی شاہ بھیس میں ڈی جی ایس حامد میر           1.0
# 4                            قابل اعتبار قاتل اعتبار           1.0
#
#    Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5 Unnamed: 6  Unnamed: 7
# 0         NaN         NaN         NaN         NaN        NaN         NaN
# 1         NaN         NaN         NaN         NaN        NaN         NaN
# 2         NaN         NaN         NaN         NaN        NaN         NaN
# 3         NaN         NaN         NaN         NaN        NaN         NaN
# 4         NaN         NaN         NaN         NaN        NaN         NaN

# %% [markdown]
# # Phase 3: Feature Extraction from Urdu Text
# 1. Tokenization:
# o Implement word tokenization for Urdu text, ensuring that the Urdu script is
# properly segmented into words. You can use existing tokenizers or build your
# own.
# o Deliverable: Provide a tokenized version of several Urdu social media posts.

# %%
import pandas as pd


file_path = 'lemmatized_urdu.csv'  
df = pd.read_csv(file_path, encoding='utf-8')


first_column = df.columns[0]


def urdu_tokenizer(text):
    tokens = text.split() 
    unique_tokens = list(set(tokens))  
    return unique_tokens

df['tokenized_text'] = df[first_column].apply(lambda x: urdu_tokenizer(str(x)))

print("\nTokenized Dataset of each sentence (first 5 rows):")
print(df[['tokenized_text']].head())

output_file_path = 'tokenized_urdu.csv'
df.to_csv(output_file_path, index=False, encoding='utf-8')
# Out:
# Tokenized Dataset of each sentence (first 5 rows):
#                                       tokenized_text
# 0       [میری, فسادن, چاہیے, لینے, نہیں, شادی, کوجی]
# 1  [کر, میں, چل, چڑیل, نوں, چاچی, سرو, دسدی, آں, ...
# 2  [ہےہمیں, فالوکریں, نوٹ, دن, پربھونکناہےآپ, اپو...
# 3  [حامد, مراد, میں, جی, ایس, شاہ, بھیس, علی, ڈی,...
# 4                               [قاتل, قابل, اعتبار]

# %%
from collections import Counter

file_path = 'lemmatized_urdu.csv'  
df = pd.read_csv(file_path, encoding='utf-8')

first_column = df.columns[0]

def urdu_tokenizer(text):
    tokens = text.split()  
    return tokens

all_tokens = []

for text in df[first_column]:
    tokens = urdu_tokenizer(str(text))
    all_tokens.extend(tokens)  

token_frequency = Counter(all_tokens)

sorted_token_frequency = sorted(token_frequency.items(), key=lambda x: x[1], reverse=True)

print("\nTokenized Corpus and Frequency:")
for token, freq in sorted_token_frequency:
    print(f"Token: {token}, Frequency: {freq}")
# Out:
# Tokenized Corpus and Frequency:
# Token: میں, Frequency: 7323
# Token: کو, Frequency: 5640
# Token: سے, Frequency: 5471
# Token: کر, Frequency: 5252
# Token: کا, Frequency: 4966
# Token: نہیں, Frequency: 4445
# Token: بھی, Frequency: 3890
# Token: نے, Frequency: 3711
# Token: اس, Frequency: 2161
# Token: آپ, Frequency: 2105
# Token: جا, Frequency: 1975
# Token: وہ, Frequency: 1821
# Token: جو, Frequency: 1389
# Token: تھا, Frequency: 1359
# Token: نہ, Frequency: 1341
# Token: اب, Frequency: 1270
# Token: خان, Frequency: 1161
# Token: ھے, Frequency: 1147
# Token: ہم, Frequency: 1028
# Token: گا, Frequency: 1007
# Token: اللہ, Frequency: 1006
# Token: بات, Frequency: 989
# Token: جی, Frequency: 961
# Token: سب, Frequency: 957
# Token: صاحب, Frequency: 951
# Token: تم, Frequency: 887
# Token: ان, Frequency: 854
# Token: کسی, Frequency: 850
# Token: رہا, Frequency: 832
# Token: پاکستان, Frequency: 822
# Token: بہت, Frequency: 816
# Token: سندھ, Frequency: 811
# Token: کرنے, Frequency: 794
# Token: ا, Frequency: 793
# Token: دیا, Frequency: 790
# Token: کچھ, Frequency: 783
# Token: جب, Frequency: 741
# Token: آ, Frequency: 741
# Token: نواز, Frequency: 710
# Token: اے, Frequency: 707
# Token: عمران, Frequency: 690
# Token: اگر, Frequency: 688
# Token: پہ, Frequency: 683
# Token: حکومت, Frequency: 680
# Token: ہوتا, Frequency: 677
# Token: جس, Frequency: 676
# Token: اپنی, Frequency: 673
# Token: اپنے, Frequency: 663
# Token: ساتھ, Frequency: 662
# Token: تنقید, Frequency: 647
# Token: یا, Frequency: 644
# Token: مجھے, Frequency: 643
# Token: لیکن, Frequency: 632
# Token: شریف, Frequency: 627
# Token: نا, Frequency: 603
# Token: پولیس, Frequency: 599
# Token: جائے, Frequency: 566
# Token: ن, Frequency: 562
# Token: لیے, Frequency: 559
# Token: لگ, Frequency: 556
# Token: بلاول, Frequency: 549
# Token: پہلے, Frequency: 544
# Token: بس, Frequency: 537
# Token: پی, Frequency: 531
# Token: دل, Frequency: 528
# Token: م, Frequency: 526
# Token: مریم, Frequency: 524
# Token: تے, Frequency: 516
# Token: دیکھ, Frequency: 501
# Token: کہ, Frequency: 497
# Token: میرے, Frequency: 496
# Token: صرف, Frequency: 495
# Token: خود, Frequency: 490
# Token: لے, Frequency: 488
# Token: صفدر, Frequency: 485
# Token: کبھی, Frequency: 480
# Token: میری, Frequency: 467
# Token: ہونے, Frequency: 466
# Token: بے, Frequency: 451
# Token: وقت, Frequency: 451
# Token: بعد, Frequency: 445
# Token: دن, Frequency: 442
# Token: مگر, Frequency: 438
# Token: مل, Frequency: 433
# Token: فوج, Frequency: 429
# Token: والا, Frequency: 428
# Token: مزاح, Frequency: 424
# Token: کام, Frequency: 418
# Token: جیسے, Frequency: 416
# Token: کرنا, Frequency: 414
# Token: بھائی, Frequency: 409
# Token: t, Frequency: 408
# Token: co, Frequency: 407
# Token: نام, Frequency: 402
# Token: سمجھ, Frequency: 401
# Token: میرا, Frequency: 399
# Token: عوام, Frequency: 393
# Token: عزت, Frequency: 392
# Token: ملک, Frequency: 387
# Token: اپنا, Frequency: 386
# Token: روپے, Frequency: 382
# Token: بنا, Frequency: 379
# Token: ل, Frequency: 378
# Token: ابھی, Frequency: 368
# Token: طرح, Frequency: 363
# Token: ایسے, Frequency: 354
# Token: گھر, Frequency: 351
# Token: زیادہ, Frequency: 350
# Token: بن, Frequency: 349
# Token: والوں, Frequency: 347
# Token: کرتا, Frequency: 346
# Token: س, Frequency: 340
# Token: سی, Frequency: 335
# Token: ڈی, Frequency: 334
# Token: لگا, Frequency: 334
# Token: زندگی, Frequency: 333
# Token: پتہ, Frequency: 332
# Token: پاس, Frequency: 328
# Token: کون, Frequency: 328
# Token: چیف, Frequency: 325
# Token: والی, Frequency: 322
# Token: فالو, Frequency: 319
# Token: کم, Frequency: 317
# Token: کس, Frequency: 311
# Token: محبت, Frequency: 311
# Token: دنیا, Frequency: 310
# Token: ہ, Frequency: 309
# Token: اچھا, Frequency: 307
# Token: ویسے, Frequency: 303
# Token: خوش, Frequency: 303
# Token: ختم, Frequency: 303
# Token: جاتے, Frequency: 303
# Token: او, Frequency: 301
# Token: سکتا, Frequency: 299
# Token: دیں, Frequency: 298
# Token: آمین, Frequency: 298
# Token: نانی, Frequency: 296
# Token: وی, Frequency: 296
# Token: آرمی, Frequency: 295
# Token: اسے, Frequency: 294
# Token: سر, Frequency: 289
# Token: بی, Frequency: 286
# Token: ھو, Frequency: 283
# Token: پاک, Frequency: 277
# Token: بار, Frequency: 276
# Token: ہمارے, Frequency: 275
# Token: کہہ, Frequency: 272
# Token: یاد, Frequency: 271
# Token: لکھ, Frequency: 271
# Token: کیسے, Frequency: 270
# Token: لیگ, Frequency: 266
# Token: زرداری, Frequency: 263
# Token: منہ, Frequency: 263
# Token: وزیراعظم, Frequency: 261
# Token: کیونکہ, Frequency: 258
# Token: ایسا, Frequency: 254
# Token: پوری, Frequency: 251
# Token: سن, Frequency: 249
# Token: تیری, Frequency: 247
# Token: نظر, Frequency: 246
# Token: انسان, Frequency: 246
# Token: ٹی, Frequency: 245
# Token: اتنی, Frequency: 244
# Token: چور, Frequency: 242
# Token: چل, Frequency: 241
# Token: ہمیں, Frequency: 241
# Token: اتنا, Frequency: 240
# Token: نیازی, Frequency: 240
# Token: کراچی, Frequency: 239
# Token: جانے, Frequency: 239
# Token: کیپٹن, Frequency: 238
# Token: اسی, Frequency: 237
# Token: سو, Frequency: 237
# Token: طنز, Frequency: 237
# Token: جواب, Frequency: 236
# Token: جاتی, Frequency: 233
# Token: دا, Frequency: 233
# Token: نہی, Frequency: 231
# Token: یہی, Frequency: 231
# Token: وہی, Frequency: 229
# Token: شروع, Frequency: 229
# Token: سال, Frequency: 229
# Token: میاں, Frequency: 227
# Token: ہمیشہ, Frequency: 227
# Token: ساری, Frequency: 227
# Token: باقی, Frequency: 226
# Token: ہوگا, Frequency: 225
# Token: ہمارا, Frequency: 224
# Token: عورت, Frequency: 221
# Token: اغوا, Frequency: 221
# Token: خیر, Frequency: 219
# Token: الل, Frequency: 218
# Token: قوم, Frequency: 217
# Token: اپوزیشن, Frequency: 216
# Token: مطلب, Frequency: 215
# Token: سیاست, Frequency: 213
# Token: ایم, Frequency: 213
# Token: شکریہ, Frequency: 212
# Token: کھا, Frequency: 212
# Token: جن, Frequency: 212
# Token: سارے, Frequency: 210
# Token: تیرے, Frequency: 209
# Token: بھٹو, Frequency: 206
# Token: جزاک, Frequency: 206
# Token: کیڑا, Frequency: 206
# Token: د, Frequency: 205
# Token: sarcasm, Frequency: 205
# Token: علی, Frequency: 204
# Token: ٹویٹ, Frequency: 204
# Token: پٹواری, Frequency: 201
# Token: چاہیے, Frequency: 200
# Token: خلاف, Frequency: 200
# Token: ووٹ, Frequency: 199
# Token: فرمائے, Frequency: 198
# Token: بڑا, Frequency: 198
# Token: اک, Frequency: 197
# Token: رات, Frequency: 197
# Token: دونوں, Frequency: 197
# Token: ہاتھ, Frequency: 195
# Token: میڈیا, Frequency: 195
# Token: جلسے, Frequency: 194
# Token: پاکستانی, Frequency: 193
# Token: کامران, Frequency: 190
# Token: دینے, Frequency: 189
# Token: اپ, Frequency: 188
# Token: سکتے, Frequency: 187
# Token: ایس, Frequency: 186
# Token: وزیر, Frequency: 186
# Token: کہاں, Frequency: 186
# Token: ہماری, Frequency: 185
# Token: چیز, Frequency: 184
# Token: بتا, Frequency: 183
# Token: جان, Frequency: 183
# Token: زندہ, Frequency: 183
# Token: Sarcasm, Frequency: 183
# Token: ہوگیا, Frequency: 182
# Token: اردو, Frequency: 182
# Token: بہن, Frequency: 179
# Token: انڈے, Frequency: 179
# Token: سیاسی, Frequency: 177
# Token: باجوہ, Frequency: 177
# Token: علیہ, Frequency: 175
# Token: ہونا, Frequency: 174
# Token: وجہ, Frequency: 174
# Token: یار, Frequency: 172
# Token: ایسی, Frequency: 172
# Token: واہ, Frequency: 170
# Token: عطا, Frequency: 170
# Token: یہاں, Frequency: 169
# Token: گل, Frequency: 167
# Token: رہیں, Frequency: 167
# Token: ھیں, Frequency: 165
# Token: واپس, Frequency: 164
# Token: رہ, Frequency: 163
# Token: تمام, Frequency: 163
# Token: پارٹی, Frequency: 163
# Token: بڑی, Frequency: 162
# Token: جگہ, Frequency: 161
# Token: گرفتار, Frequency: 160
# Token: مجھ, Frequency: 159
# Token: دوسرے, Frequency: 158
# Token: میر, Frequency: 157
# Token: چاہ, Frequency: 157
# Token: بیک, Frequency: 157
# Token: چھوڑ, Frequency: 156
# Token: بندہ, Frequency: 156
# Token: غیرت, Frequency: 155
# Token: اندر, Frequency: 154
# Token: اردو_زبان, Frequency: 153
# Token: پتا, Frequency: 152
# Token: دعا, Frequency: 152
# Token: دینا, Frequency: 151
# Token: شخص, Frequency: 151
# Token: ورنہ, Frequency: 151
# Token: آتی, Frequency: 150
# Token: ماں, Frequency: 150
# Token: نوٹس, Frequency: 149
# Token: سا, Frequency: 147
# Token: نکل, Frequency: 147
# Token: بڑے, Frequency: 146
# Token: چھٹی, Frequency: 146
# Token: مہنگائی, Frequency: 144
# Token: سچ, Frequency: 144
# Token: مر, Frequency: 144
# Token: مولانا, Frequency: 144
# Token: لندن, Frequency: 144
# Token: باد, Frequency: 144
# Token: ای, Frequency: 143
# Token: مت, Frequency: 142
# Token: کوشش, Frequency: 141
# Token: صحافی, Frequency: 141
# Token: پڑھ, Frequency: 141
# Token: بہتر, Frequency: 140
# Token: چینی, Frequency: 140
# Token: دیتا, Frequency: 139
# Token: فون, Frequency: 139
# Token: ریٹویٹ, Frequency: 139
# Token: لسٹ, Frequency: 139
# Token: آتا, Frequency: 139
# Token: جانا, Frequency: 138
# Token: خبر, Frequency: 137
# Token: سوچ, Frequency: 137
# Token: باتیں, Frequency: 137
# Token: ہاں, Frequency: 136
# Token: وسلم, Frequency: 136
# Token: اعظم, Frequency: 136
# Token: پوچھ, Frequency: 136
# Token: شرم, Frequency: 136
# Token: کلو, Frequency: 136
# Token: انہیں, Frequency: 135
# Token: کپتان, Frequency: 135
# Token: کرکے, Frequency: 135
# Token: محمد, Frequency: 134
# Token: مار, Frequency: 134
# Token: کتے, Frequency: 133
# Token: نیا, Frequency: 133
# Token: مارخورز, Frequency: 132
# Token: حال, Frequency: 131
# Token: سکتی, Frequency: 131
# Token: 2, Frequency: 131
# Token: جے, Frequency: 130
# Token: غلط, Frequency: 130
# Token: صبح, Frequency: 130
# Token: آگے, Frequency: 129
# Token: کہتا, Frequency: 129
# Token: لیڈر, Frequency: 129
# Token: 100, Frequency: 129
# Token: ڈاکٹر, Frequency: 128
# Token: بند, Frequency: 127
# Token: بیٹھ, Frequency: 127
# Token: باپ, Frequency: 127
# Token: یقین, Frequency: 127
# Token: ملے, Frequency: 126
# Token: بھر, Frequency: 126
# Token: وہاں, Frequency: 126
# Token: زبان, Frequency: 125
# Token: باہر, Frequency: 125
# Token: ح, Frequency: 124
# Token: پٹواریوں, Frequency: 124
# Token: اضافہ, Frequency: 124
# Token: شامل, Frequency: 123
# Token: پیچھے, Frequency: 123
# Token: جہاں, Frequency: 123
# Token: گالیاں, Frequency: 123
# Token: بالکل, Frequency: 123
# Token: تب, Frequency: 122
# Token: سارا, Frequency: 120
# Token: ھی, Frequency: 120
# Token: سلام, Frequency: 120
# Token: ثابت, Frequency: 120
# Token: سامنے, Frequency: 120
# Token: السلام, Frequency: 120
# Token: عشق, Frequency: 119
# Token: حق, Frequency: 119
# Token: بچے, Frequency: 119
# Token: پڑے, Frequency: 119
# Token: صلی, Frequency: 119
# Token: بغیر, Frequency: 118
# Token: بلکہ, Frequency: 118
# Token: نوازشریف, Frequency: 118
# Token: نمبر, Frequency: 118
# Token: ڈال, Frequency: 118
# Token: درجن, Frequency: 117
# Token: ترین, Frequency: 117
# Token: فالورز, Frequency: 116
# Token: 1, Frequency: 115
# Token: استعمال, Frequency: 114
# Token: تسی, Frequency: 113
# Token: جج, Frequency: 113
# Token: بول, Frequency: 113
# Token: تین, Frequency: 113
# Token: پے, Frequency: 113
# Token: خیال, Frequency: 113
# Token: لینے, Frequency: 112
# Token: شادی, Frequency: 112
# Token: آپکی, Frequency: 112
# Token: خدا, Frequency: 112
# Token: کہنا, Frequency: 112
# Token: شیر, Frequency: 112
# Token: بلکل, Frequency: 112
# Token: تبدیلی, Frequency: 111
# Token: صحافت, Frequency: 111
# Token: رکھ, Frequency: 111
# Token: انڈیا, Frequency: 111
# Token: آخری, Frequency: 111
# Token: گئ, Frequency: 110
# Token: آپکو, Frequency: 110
# Token: آنے, Frequency: 109
# Token: بتائیں, Frequency: 109
# Token: ذرا, Frequency: 109
# Token: چاہتا, Frequency: 108
# Token: کردیا, Frequency: 108
# Token: شاید, Frequency: 108
# Token: تمہیں, Frequency: 108
# Token: مذاق, Frequency: 108
# Token: بندے, Frequency: 108
# Token: فوجی, Frequency: 107
# Token: جلدی, Frequency: 107
# Token: تمہارے, Frequency: 107
# Token: کروا, Frequency: 107
# Token: سوال, Frequency: 107
# Token: لعنت, Frequency: 107
# Token: جنرل, Frequency: 107
# Token: پسند, Frequency: 107
# Token: رب, Frequency: 107
# Token: صحت, Frequency: 106
# Token: جناب, Frequency: 106
# Token: تقریر, Frequency: 106
# Token: حامد, Frequency: 105
# Token: جیسا, Frequency: 105
# Token: خراب, Frequency: 105
# Token: ریٹوئیٹ, Frequency: 105
# Token: جاؤ, Frequency: 105
# Token: کرنی, Frequency: 105
# Token: کافی, Frequency: 104
# Token: چار, Frequency: 104
# Token: ہائے, Frequency: 104
# Token: ترقی, Frequency: 104
# Token: فٹ, Frequency: 104
# Token: خواب, Frequency: 103
# Token: جبکہ, Frequency: 103
# Token: کمال, Frequency: 103
# Token: رکھنا, Frequency: 103
# Token: پنجاب, Frequency: 101
# Token: لینا, Frequency: 101
# Token: ہوگی, Frequency: 101
# Token: مشکل, Frequency: 100
# Token: غم, Frequency: 100
# Token: اوپر, Frequency: 100
# Token: اصل, Frequency: 100
# Token: پیدا, Frequency: 100
# Token: ڈیزل, Frequency: 99
# Token: کوئ, Frequency: 99
# Token: آپکے, Frequency: 99
# Token: انصاف, Frequency: 99
# Token: فیر, Frequency: 99
# Token: پ, Frequency: 98
# Token: StateAboveStateRejected, Frequency: 98
# Token: بابا, Frequency: 98
# Token: 200, Frequency: 98
# Token: پورے, Frequency: 97
# Token: جیسی, Frequency: 97
# Token: بنے, Frequency: 97
# Token: داری, Frequency: 96
# Token: شاہ, Frequency: 96
# Token: اسکی, Frequency: 96
# Token: اسکے, Frequency: 96
# Token: مرشد, Frequency: 96
# Token: حاصل, Frequency: 96
# Token: غیر, Frequency: 96
# Token: حرام, Frequency: 95
# Token: جھوٹ, Frequency: 95
# Token: شہباز, Frequency: 95
# Token: بدل, Frequency: 95
# Token: درد, Frequency: 95
# Token: فراز, Frequency: 95
# Token: دوں, Frequency: 94
# Token: بچوں, Frequency: 94
# Token: دکھ, Frequency: 94
# Token: کروڑ, Frequency: 94
# Token: آدمی, Frequency: 94
# Token: کہنے, Frequency: 93
# Token: وآلہ, Frequency: 93
# Token: تاریخ, Frequency: 92
# Token: مینشن, Frequency: 92
# Token: دیکھنا, Frequency: 92
# Token: اسکا, Frequency: 92
# Token: لڑکی, Frequency: 91
# Token: بجائے, Frequency: 91
# Token: کتا, Frequency: 91
# Token: ذلیل, Frequency: 91
# Token: پانی, Frequency: 91
# Token: الیکشن, Frequency: 91
# Token: انکی, Frequency: 91
# Token: حسین, Frequency: 91
# Token: WeStandWithSindhPolice, Frequency: 91
# Token: نئی, Frequency: 91
# Token: ڈر, Frequency: 91
# Token: جاری, Frequency: 91
# Token: تجھے, Frequency: 91
# Token: عمر, Frequency: 90
# Token: الفاظ, Frequency: 90
# Token: مرضی, Frequency: 90
# Token: شک, Frequency: 90
# Token: نوں, Frequency: 89
# Token: جیل, Frequency: 89
# Token: کھانے, Frequency: 89
# Token: نون, Frequency: 89
# Token: چ, Frequency: 89
# Token: بنانے, Frequency: 89
# Token: تعلق, Frequency: 89
# Token: ﷺ, Frequency: 88
# Token: کتنا, Frequency: 88
# Token: تحقیقات, Frequency: 88
# Token: نعرہ, Frequency: 88
# Token: درست, Frequency: 88
# Token: تیرا, Frequency: 88
# Token: سہی, Frequency: 88
# Token: پڑ, Frequency: 88
# Token: بیوی, Frequency: 88
# Token: آر, Frequency: 88
# Token: اغواء, Frequency: 88
# Token: مبارک, Frequency: 87
# Token: تحریک, Frequency: 87
# Token: جتنی, Frequency: 87
# Token: گرفتاری, Frequency: 87
# Token: اتنے, Frequency: 87
# Token: نئیں, Frequency: 86
# Token: ي, Frequency: 86
# Token: فیصلہ, Frequency: 86
# Token: سوشل, Frequency: 86
# Token: کتنی, Frequency: 85
# Token: درخواست, Frequency: 85
# Token: آواز, Frequency: 85
# Token: حس, Frequency: 85
# Token: حد, Frequency: 85
# Token: آتے, Frequency: 85
# Token: دوسروں, Frequency: 84
# Token: بیٹی, Frequency: 84
# Token: دماغ, Frequency: 84
# Token: فرق, Frequency: 84
# Token: لاکھ, Frequency: 84
# Token: رہتا, Frequency: 84
# Token: موقع, Frequency: 84
# Token: بیان, Frequency: 83
# Token: بہترین, Frequency: 83
# Token: اوقات, Frequency: 83
# Token: مکمل, Frequency: 82
# Token: شام, Frequency: 82
# Token: بیٹا, Frequency: 82
# Token: کتنے, Frequency: 82
# Token: موبائل, Frequency: 82
# Token: جلسہ, Frequency: 82
# Token: نوٹ, Frequency: 81
# Token: شکر, Frequency: 81
# Token: موت, Frequency: 81
# Token: پاکستانیوں, Frequency: 81
# Token: تمہاری, Frequency: 81
# Token: ریاست, Frequency: 81
# Token: پیار, Frequency: 81
# Token: مزید, Frequency: 80
# Token: مرد, Frequency: 80
# Token: جلد, Frequency: 80
# Token: پیپلز, Frequency: 80
# Token: رو, Frequency: 80
# Token: ص, Frequency: 79
# Token: ہا, Frequency: 79
# Token: ٹویٹر, Frequency: 79
# Token: پڑتا, Frequency: 79
# Token: کرونا, Frequency: 79
# Token: برداشت, Frequency: 79
# Token: آگ, Frequency: 79
# Token: رکھیں, Frequency: 79
# Token: رہتے, Frequency: 79
# Token: نال, Frequency: 78
# Token: خوشی, Frequency: 78
# Token: رھے, Frequency: 78
# Token: دوسرا, Frequency: 78
# Token: قابل, Frequency: 77
# Token: پیش, Frequency: 77
# Token: لفظ, Frequency: 77
# Token: پٹواریوں_کی_مادرملت, Frequency: 77
# Token: تمہارا, Frequency: 77
# Token: قانون, Frequency: 77
# Token: یوتھیوں, Frequency: 77
# Token: یعنی, Frequency: 77
# Token: سکے, Frequency: 77
# Token: تاکہ, Frequency: 77
# Token: انہوں, Frequency: 77
# Token: موجود, Frequency: 77
# Token: روز, Frequency: 76
# Token: جسے, Frequency: 76
# Token: مند, Frequency: 76
# Token: بارے, Frequency: 76
# Token: ف, Frequency: 75
# Token: نو, Frequency: 75
# Token: بخیر, Frequency: 75
# Token: فضل, Frequency: 75
# Token: دیکھنے, Frequency: 75
# Token: حالات, Frequency: 75
# Token: گ, Frequency: 75
# Token: آصف, Frequency: 75
# Token: مراد, Frequency: 74
# Token: دوست, Frequency: 74
# Token: ش, Frequency: 74
# Token: جاۓ, Frequency: 74
# Token: رینجرز, Frequency: 74
# Token: عام, Frequency: 73
# Token: احمد, Frequency: 73
# Token: افسوس, Frequency: 73
# Token: چائے, Frequency: 73
# Token: ایچ, Frequency: 73
# Token: تھانے, Frequency: 73
# Token: کردار, Frequency: 72
# Token: عجیب, Frequency: 72
# Token: انکے, Frequency: 72
# Token: بھول, Frequency: 72
# Token: بیٹھے, Frequency: 72
# Token: توں, Frequency: 72
# Token: عمل, Frequency: 72
# Token: عقل, Frequency: 72
# Token: بچہ, Frequency: 72
# Token: غدار, Frequency: 72
# Token: اسلام, Frequency: 72
# Token: قائد, Frequency: 71
# Token: چکا, Frequency: 71
# Token: نیوز, Frequency: 71
# Token: برا, Frequency: 71
# Token: 22, Frequency: 71
# Token: سیاستدان, Frequency: 71
# Token: کورٹ, Frequency: 71
# Token: خوبصورت, Frequency: 71
# Token: نکال, Frequency: 70
# Token: ذمہ, Frequency: 70
# Token: بننے, Frequency: 70
# Token: کوئٹہ, Frequency: 70
# Token: ٹائم, Frequency: 70
# Token: تکلیف, Frequency: 70
# Token: ال, Frequency: 70
# Token: بزدار, Frequency: 69
# Token: آنا, Frequency: 69
# Token: بلاک, Frequency: 69
# Token: ابا, Frequency: 69
# Token: ہزار, Frequency: 69
# Token: شہر, Frequency: 69
# Token: کھڑے, Frequency: 69
# Token: جتنا, Frequency: 68
# Token: آباد, Frequency: 68
# Token: وچ, Frequency: 68
# Token: مقام, Frequency: 68
# Token: مطابق, Frequency: 68
# Token: بوٹ, Frequency: 68
# Token: نکلا, Frequency: 68
# Token: تصویر, Frequency: 68
# Token: چاہے, Frequency: 68
# Token: باجی, Frequency: 68
# Token: قسم, Frequency: 68
# Token: کانفرنس, Frequency: 67
# Token: کھیل, Frequency: 67
# Token: قبول, Frequency: 67
# Token: مزار, Frequency: 67
# Token: فورس, Frequency: 67
# Token: خ, Frequency: 67
# Token: باتوں, Frequency: 67
# Token: حضرت, Frequency: 67
# Token: خواہش, Frequency: 67
# Token: خاوند, Frequency: 67
# Token: کرپشن, Frequency: 67
# Token: بکواس, Frequency: 66
# Token: استعفی, Frequency: 66
# Token: خوب, Frequency: 66
# Token: یو, Frequency: 66
# Token: معلوم, Frequency: 66
# Token: انکوائری, Frequency: 66
# Token: ھا, Frequency: 66
# Token: مجرم, Frequency: 65
# Token: پریس, Frequency: 65
# Token: غریب, Frequency: 65
# Token: شیخ, Frequency: 65
# Token: افسران, Frequency: 65
# Token: ادا, Frequency: 65
# Token: غلطی, Frequency: 65
# Token: جسٹس, Frequency: 65
# Token: صحافیوں, Frequency: 64
# Token: برکت, Frequency: 64
# Token: دکھا, Frequency: 64
# Token: غائب, Frequency: 63
# Token: تیار, Frequency: 63
# Token: پچھلے, Frequency: 63
# Token: جیو, Frequency: 63
# Token: نیند, Frequency: 63
# Token: اعوان, Frequency: 63
# Token: واقعی, Frequency: 63
# Token: ٹیم, Frequency: 63
# Token: شبلی, Frequency: 63
# Token: تا, Frequency: 63
# Token: تعریف, Frequency: 63
# Token: رشتے, Frequency: 63
# Token: حقیقت, Frequency: 63
# Token: لیتا, Frequency: 63
# Token: سزا, Frequency: 63
# Token: بحث, Frequency: 63
# Token: محفل_سخن, Frequency: 63
# Token: گلی, Frequency: 62
# Token: سکون, Frequency: 62
# Token: حساب, Frequency: 62
# Token: چوری, Frequency: 62
# Token: کروں, Frequency: 62
# Token: دار, Frequency: 62
# Token: 300, Frequency: 62
# Token: PDM, Frequency: 62
# Token: سوچا, Frequency: 62
# Token: اگلے, Frequency: 61
# Token: رشید, Frequency: 61
# Token: بولا, Frequency: 61
# Token: انکو, Frequency: 61
# Token: حالت, Frequency: 61
# Token: انتظار, Frequency: 61
# Token: الزام, Frequency: 61
# Token: ھم, Frequency: 61
# Token: شکل, Frequency: 61
# Token: انشاءاللہ, Frequency: 61
# Token: این, Frequency: 61
# Token: اعلی, Frequency: 60
# Token: بد, Frequency: 60
# Token: نیچے, Frequency: 60
# Token: اعلان, Frequency: 60
# Token: ہنس, Frequency: 60
# Token: اسکو, Frequency: 60
# Token: صحیح, Frequency: 60
# Token: پیسے, Frequency: 60
# Token: مولوی, Frequency: 60
# Token: قومی, Frequency: 60
# Token: عثمان, Frequency: 59
# Token: اج, Frequency: 59
# Token: بیچ, Frequency: 59
# Token: نیو, Frequency: 59
# Token: گھٹیا, Frequency: 59
# Token: دوسری, Frequency: 59
# Token: پلیز, Frequency: 59
# Token: قبر, Frequency: 59
# Token: دشمن, Frequency: 59
# Token: گندے, Frequency: 59
# Token: چوہدری, Frequency: 59
# Token: نعرے, Frequency: 59
# Token: رنگ, Frequency: 59
# Token: خاتم_النبیین_محمدﷺ, Frequency: 58
# Token: خاص, Frequency: 58
# Token: چند, Frequency: 58
# Token: کتاب, Frequency: 58
# Token: فیصد, Frequency: 58
# Token: کدو, Frequency: 57
# Token: الله, Frequency: 57
# Token: برابر, Frequency: 57
# Token: آئ, Frequency: 57
# Token: ھوں, Frequency: 57
# Token: توڑ, Frequency: 57
# Token: ماشاءاللہ, Frequency: 57
# Token: سانپ, Frequency: 57
# Token: مشکلات, Frequency: 57
# Token: بیچارے, Frequency: 56
# Token: مادر, Frequency: 56
# Token: یوتھیے, Frequency: 56
# Token: بھاگ, Frequency: 56
# Token: از, Frequency: 56
# Token: پا, Frequency: 56
# Token: نصیب, Frequency: 56
# Token: چوروں, Frequency: 56
# Token: وغیرہ, Frequency: 56
# Token: رہو, Frequency: 56
# Token: ویڈیو, Frequency: 56
# Token: فرمایا, Frequency: 56
# Token: بزدارکی_پرواز_بلاول_بیکار, Frequency: 55
# Token: 11, Frequency: 55
# Token: ادب_کا_سفر, Frequency: 55
# Token: مخلوق, Frequency: 55
# Token: مانگ, Frequency: 55
# Token: صل, Frequency: 55
# Token: آلو, Frequency: 55
# Token: 3, Frequency: 55
# Token: آف, Frequency: 55
# Token: ك, Frequency: 55
# Token: غصہ, Frequency: 55
# Token: سپریم, Frequency: 55
# Token: قدر, Frequency: 54
# Token: ڈرامہ, Frequency: 54
# Token: دینی, Frequency: 54
# Token: ھوا, Frequency: 54
# Token: آسان, Frequency: 54
# Token: پروگرام, Frequency: 54
# Token: غزوۂ, Frequency: 54
# Token: اندازہ, Frequency: 54
# Token: جینا, Frequency: 54
# Token: چلتا, Frequency: 54
# Token: پہنچ, Frequency: 54
# Token: پوسٹ, Frequency: 54
# Token: ثبوت, Frequency: 54
# Token: وعلیکم, Frequency: 54
# Token: انقلاب, Frequency: 53
# Token: بنتا, Frequency: 53
# Token: گر, Frequency: 53
# Token: رہنے, Frequency: 53
# Token: جیت, Frequency: 53
# Token: چکر, Frequency: 53
# Token: ری, Frequency: 53
# Token: اقبال, Frequency: 53
# Token: نفرت, Frequency: 53
# Token: امریکہ, Frequency: 53
# Token: استغفر, Frequency: 53
# Token: اللهہ, Frequency: 53
# Token: واتوب, Frequency: 53
# Token: مدد, Frequency: 52
# Token: پاگل, Frequency: 52
# Token: مان, Frequency: 52
# Token: لڑائی, Frequency: 52
# Token: آنکھوں, Frequency: 52
# Token: آگیا, Frequency: 52
# Token: حصہ, Frequency: 52
# Token: ماہ, Frequency: 52
# Token: اکاؤنٹ, Frequency: 52
# Token: یوں, Frequency: 52
# Token: سلامت, Frequency: 52
# Token: رزق, Frequency: 52
# Token: ملی, Frequency: 51
# Token: سالوں, Frequency: 51
# Token: مدت, Frequency: 51
# Token: گھنٹے, Frequency: 51
# Token: کروایا, Frequency: 51
# Token: فیصل, Frequency: 51
# Token: سازی, Frequency: 51
# Token: فائدہ, Frequency: 51
# Token: ٹ, Frequency: 51
# Token: ہاتھوں, Frequency: 51
# Token: ایف, Frequency: 51
# Token: ہنسی, Frequency: 51
# Token: صبر, Frequency: 51
# Token: شور, Frequency: 51
# Token: جاؤں, Frequency: 51
# Token: تعال, Frequency: 51
# Token: اليهہ, Frequency: 51
# Token: آل, Frequency: 50
# Token: بسکٹ, Frequency: 50
# Token: سیریس, Frequency: 50
# Token: کال, Frequency: 50
# Token: کاٹ, Frequency: 50
# Token: اولاد, Frequency: 50
# Token: جانتے, Frequency: 50
# Token: دس, Frequency: 50
# Token: بریانی, Frequency: 50
# Token: دیے, Frequency: 50
# Token: خاندان, Frequency: 50
# Token: سرکاری, Frequency: 50
# Token: پرانے, Frequency: 50
# Token: تنگ, Frequency: 50
# Token: امید, Frequency: 50
# Token: بڑھ, Frequency: 50
# Token: کاش, Frequency: 50
# Token: امی, Frequency: 50
# Token: تندرستی, Frequency: 50
# Token: گدھا, Frequency: 49
# Token: محترمہ, Frequency: 49
# Token: رپورٹ, Frequency: 49
# Token: گالی, Frequency: 49
# Token: پڑی, Frequency: 49
# Token: وں, Frequency: 49
# Token: آپشن, Frequency: 49
# Token: کونسا, Frequency: 49
# Token: مارکیٹ, Frequency: 49
# Token: تعالی, Frequency: 49
# Token: بولنے, Frequency: 49
# Token: معصوم, Frequency: 49
# Token: مسلم, Frequency: 49
# Token: گیم, Frequency: 48
# Token: حکم, Frequency: 48
# Token: حسن, Frequency: 48
# Token: بیانیہ, Frequency: 48
# Token: مزے, Frequency: 48
# Token: دوستوں, Frequency: 48
# Token: کرپٹ, Frequency: 48
# Token: بھلا, Frequency: 48
# Token: لگایا, Frequency: 48
# Token: تنظیم, Frequency: 48
# Token: نماز, Frequency: 48
# Token: پکڑ, Frequency: 48
# Token: لئیے, Frequency: 48
# Token: قصور, Frequency: 48
# Token: معاملے, Frequency: 48
# Token: مدینہ, Frequency: 48
# Token: پیاری, Frequency: 48
# Token: گناہ, Frequency: 48
# Token: تھیں, Frequency: 48
# Token: شرمندہ, Frequency: 48
# Token: تجھ, Frequency: 48
# Token: دوبارہ, Frequency: 47
# Token: سمجھدار, Frequency: 47
# Token: گدھے, Frequency: 47
# Token: کمانڈر, Frequency: 47
# Token: سوا, Frequency: 47
# Token: لگانے, Frequency: 47
# Token: آئین, Frequency: 47
# Token: آٹا, Frequency: 47
# Token: شوق, Frequency: 47
# Token: مطالبہ, Frequency: 47
# Token: علیکم, Frequency: 47
# Token: الرحمن, Frequency: 47
# Token: آنکھ, Frequency: 47
# Token: لوٹ, Frequency: 47
# Token: لاہور, Frequency: 47
# Token: کنٹینر, Frequency: 47
# Token: خاک, Frequency: 47
# Token: ملتا, Frequency: 47
# Token: راہ, Frequency: 46
# Token: برباد, Frequency: 46
# Token: بلا, Frequency: 46
# Token: کنجر, Frequency: 46
# Token: نیک, Frequency: 46
# Token: چاٹ, Frequency: 46
# Token: تربیت, Frequency: 46
# Token: اختیار, Frequency: 46
# Token: محنت, Frequency: 46
# Token: فری, Frequency: 46
# Token: چپ, Frequency: 46
# Token: محترم, Frequency: 46
# Token: رہنا, Frequency: 46
# Token: سخت, Frequency: 46
# Token: اوہ, Frequency: 46
# Token: ہونگے, Frequency: 46
# Token: کھانا, Frequency: 45
# Token: اسٹیبلشمنٹ, Frequency: 45
# Token: بری, Frequency: 45
# Token: ہور, Frequency: 45
# Token: سوار, Frequency: 45
# Token: لفافے, Frequency: 45
# Token: آپس, Frequency: 45
# Token: چاہئے, Frequency: 45
# Token: چھپ, Frequency: 45
# Token: حل, Frequency: 45
# Token: نئے, Frequency: 45
# Token: کیسی, Frequency: 45
# Token: پالش, Frequency: 45
# Token: اٹھا, Frequency: 45
# Token: پریشانیوں, Frequency: 45
# Token: فالوکریں, Frequency: 44
# Token: روٹی, Frequency: 44
# Token: قطری, Frequency: 44
# Token: رانی, Frequency: 44
# Token: فیصلے, Frequency: 44
# Token: وفا, Frequency: 44
# Token: کتوں, Frequency: 44
# Token: وفاق, Frequency: 44
# Token: وطن, Frequency: 44
# Token: سیکھ, Frequency: 44
# Token: پانچ, Frequency: 44
# Token: جاو, Frequency: 44
# Token: اینکر, Frequency: 44
# Token: کسے, Frequency: 44
# Token: ناں, Frequency: 44
# Token: مثال, Frequency: 44
# Token: خاطر, Frequency: 44
# Token: PTI, Frequency: 44
# Token: میٹر, Frequency: 44
# Token: یوتھیا, Frequency: 44
# Token: ممکن, Frequency: 44
# Token: لوں, Frequency: 44
# Token: کیس, Frequency: 44
# Token: شوہر, Frequency: 44
# Token: کمرے, Frequency: 44
# Token: ماضی, Frequency: 43
# Token: مصروف, Frequency: 43
# Token: آہو, Frequency: 43
# Token: محسوس, Frequency: 43
# Token: جنت, Frequency: 43
# Token: عدت, Frequency: 43
# Token: لفافہ, Frequency: 43
# Token: ہوجائے, Frequency: 43
# Token: رھا, Frequency: 43
# Token: پنکی, Frequency: 43
# Token: الطاف, Frequency: 43
# Token: اداروں, Frequency: 43
# Token: صاحبہ, Frequency: 43
# Token: واحد, Frequency: 43
# Token: عظیم, Frequency: 43
# Token: ذات, Frequency: 43
# Token: آنکھیں, Frequency: 43
# Token: العالمین, Frequency: 43
# Token: لکھے, Frequency: 43
# Token: مسئلہ, Frequency: 43
# Token: دولت, Frequency: 42
# Token: چاہیئے, Frequency: 42
# Token: مینوں, Frequency: 42
# Token: کلاس, Frequency: 42
# Token: ٹویٹس, Frequency: 42
# Token: چھتر, Frequency: 42
# Token: مجبور, Frequency: 42
# Token: فارغ, Frequency: 42
# Token: مارنے, Frequency: 42
# Token: 25, Frequency: 42
# Token: مرے, Frequency: 42
# Token: چاند, Frequency: 42
# Token: باز, Frequency: 42
# Token: انکا, Frequency: 42
# Token: توبہ, Frequency: 42
# Token: اگلی, Frequency: 42
# Token: خاموش, Frequency: 42
# Token: سات, Frequency: 42
# Token: جنگ, Frequency: 42
# Token: کپٹن, Frequency: 41
# Token: دیکھے, Frequency: 41
# Token: کوٸی, Frequency: 41
# Token: آلو200روپےدرجن, Frequency: 41
# Token: کیسا, Frequency: 41
# Token: ریٹ, Frequency: 41
# Token: فکر, Frequency: 41
# Token: ورحمتہ, Frequency: 41
# Token: ابو, Frequency: 41
# Token: رکھنے, Frequency: 41
# Token: بھارت, Frequency: 41
# Token: لکھنے, Frequency: 41
# Token: کھول, Frequency: 41
# Token: جمہوریت, Frequency: 41
# Token: گئیں, Frequency: 41
# Token: احساس, Frequency: 41
# Token: حرامی, Frequency: 41
# Token: اردوزبان, Frequency: 41
# Token: اسمبلی, Frequency: 40
# Token: زرا, Frequency: 40
# Token: چھٹیوں, Frequency: 40
# Token: کردے, Frequency: 40
# Token: گولی, Frequency: 40
# Token: لانے, Frequency: 40
# Token: 5, Frequency: 40
# Token: ے, Frequency: 40
# Token: خاتون, Frequency: 40
# Token: حالانکہ, Frequency: 40
# Token: مٹا, Frequency: 40
# Token: پنجابی, Frequency: 40
# Token: پیٹ, Frequency: 40
# Token: دم, Frequency: 40
# Token: نکلے, Frequency: 40
# Token: پڑا, Frequency: 40
# Token: کروائی, Frequency: 40
# Token: لنڈے, Frequency: 40
# Token: صاب, Frequency: 40
# Token: شاعری, Frequency: 40
# Token: خطاب, Frequency: 40
# Token: ISPR, Frequency: 39
# Token: 20, Frequency: 39
# Token: قرآن, Frequency: 39
# Token: ماری, Frequency: 39
# Token: رسول, Frequency: 39
# Token: قسمت, Frequency: 39
# Token: ارے, Frequency: 39
# Token: لڑکیوں, Frequency: 39
# Token: اعتراض, Frequency: 39
# Token: لیئے, Frequency: 39
# Token: لڑکیاں, Frequency: 39
# Token: اثر, Frequency: 39
# Token: بنی, Frequency: 39
# Token: SindhPolice, Frequency: 39
# Token: کپڑے, Frequency: 39
# Token: سونا1لاکھ, Frequency: 39
# Token: مقابلہ, Frequency: 39
# Token: پتر, Frequency: 39
# Token: اہل, Frequency: 39
# Token: مانتے, Frequency: 39
# Token: را, Frequency: 39
# Token: بتاو, Frequency: 39
# Token: زمین, Frequency: 39
# Token: سرکار, Frequency: 39
# Token: آپکا, Frequency: 39
# Token: وبرکاتہ, Frequency: 39
# Token: سمجھنے, Frequency: 39
# Token: علاج, Frequency: 39
# Token: لیکر, Frequency: 39
# Token: مقدر, Frequency: 39
# Token: جاہل, Frequency: 39
# Token: سیٹ, Frequency: 39
# Token: چوہدریوں, Frequency: 39
# Token: ھ, Frequency: 39
# Token: پین, Frequency: 38
# Token: کان, Frequency: 38
# Token: نی, Frequency: 38
# Token: ملازم, Frequency: 38
# Token: قریب, Frequency: 38
# Token: عادت, Frequency: 38
# Token: کاکا, Frequency: 38
# Token: خون, Frequency: 38
# Token: تیل, Frequency: 38
# Token: توجہ, Frequency: 38
# Token: سائنسدان, Frequency: 38
# Token: بولو, Frequency: 38
# Token: پڑھنے, Frequency: 38
# Token: بھیج, Frequency: 38
# Token: رشتہ, Frequency: 38
# Token: پیج, Frequency: 38
# Token: بازار, Frequency: 38
# Token: کردی, Frequency: 38
# Token: امام, Frequency: 38
# Token: ہٹ, Frequency: 38
# Token: رانا, Frequency: 38
# Token: ہار, Frequency: 38
# Token: بازی, Frequency: 38
# Token: کمزور, Frequency: 38
# Token: اختلاف, Frequency: 38
# Token: سانس, Frequency: 38
# Token: مارچ, Frequency: 38
# Token: انتہائی, Frequency: 37
# Token: لگاتے, Frequency: 37
# Token: بلو, Frequency: 37
# Token: دیو, Frequency: 37
# Token: یے, Frequency: 37
# Token: فضول, Frequency: 37
# Token: پوچھنا, Frequency: 37
# Token: وا, Frequency: 37
# Token: ہونی, Frequency: 37
# Token: انڈے200کلو, Frequency: 37
# Token: روپےمربع, Frequency: 37
# Token: چیک, Frequency: 37
# Token: کافر, Frequency: 37
# Token: منافق, Frequency: 37
# Token: کاپی, Frequency: 37
# Token: ساڈے, Frequency: 37
# Token: رہتی, Frequency: 37
# Token: گیراج, Frequency: 37
# Token: ریٹائرڈ, Frequency: 37
# Token: ھوتی, Frequency: 37
# Token: صاف, Frequency: 37
# Token: پینے, Frequency: 37
# Token: دعوی, Frequency: 37
# Token: دنوں, Frequency: 37
# Token: اماں, Frequency: 37
# Token: سپورٹ, Frequency: 37
# Token: نشانہ, Frequency: 37
# Token: sarcastic, Frequency: 37
# Token: گز, Frequency: 36
# Token: قائم, Frequency: 36
# Token: تینوں, Frequency: 36
# Token: سنو, Frequency: 36
# Token: IG, Frequency: 36
# Token: دودھ, Frequency: 36
# Token: وردی, Frequency: 36
# Token: ٹائیگر, Frequency: 36
# Token: پیپلزپارٹی, Frequency: 36
# Token: بدلہ, Frequency: 36
# Token: بریکنگ, Frequency: 36
# Token: جلسوں, Frequency: 36
# Token: شب, Frequency: 36
# Token: جماعت, Frequency: 36
# Token: نقصان, Frequency: 36
# Token: بیٹے, Frequency: 36
# Token: نسل, Frequency: 36
# Token: مزہ, Frequency: 36
# Token: پیارے, Frequency: 36
# Token: آجائے, Frequency: 36
# Token: صوبے, Frequency: 36
# Token: ظلم, Frequency: 36
# Token: تعلیم, Frequency: 36
# Token: لائن, Frequency: 36
# Token: کامیابی, Frequency: 36
# Token: گفتگو, Frequency: 36
# Token: انگریزی, Frequency: 36
# Token: چہرے, Frequency: 36
# Token: رے, Frequency: 36
# Token: ناراض, Frequency: 36
# Token: فخر, Frequency: 36
# Token: زبردست, Frequency: 36
# Token: کونسی, Frequency: 36
# Token: ھوتا, Frequency: 36
# Token: نظیر, Frequency: 36
# Token: گلے, Frequency: 36
# Token: رکھو, Frequency: 36
# Token: ھر, Frequency: 36
# Token: پریشان, Frequency: 36
# Token: مرنے, Frequency: 36
# Token: کار, Frequency: 36
# Token: بدلتے, Frequency: 36
# Token: تباہ, Frequency: 36
# Token: گیارہ, Frequency: 35
# Token: جنم, Frequency: 35
# Token: اجازت, Frequency: 35
# Token: کشمیر, Frequency: 35
# Token: روح, Frequency: 35
# Token: غور, Frequency: 35
# Token: آن, Frequency: 35
# Token: ماموں, Frequency: 35
# Token: سلیم, Frequency: 35
# Token: بڑوں, Frequency: 35
# Token: گڈ, Frequency: 35
# Token: شرکت, Frequency: 35
# Token: روپےکلومیڑ, Frequency: 35
# Token: کالا, Frequency: 35
# Token: مرغیاں, Frequency: 35
# Token: بچت, Frequency: 35
# Token: لیٹر, Frequency: 35
# Token: کیڑے, Frequency: 35
# Token: بھئی, Frequency: 35
# Token: بوجھ, Frequency: 35
# Token: ٹرینڈ, Frequency: 35
# Token: راجہ, Frequency: 35
# Token: کھوتا, Frequency: 35
# Token: 4, Frequency: 35
# Token: علاوہ, Frequency: 35
# Token: معذرت, Frequency: 35
# Token: برطانیہ, Frequency: 35
# Token: محفوظ, Frequency: 35
# Token: پھول, Frequency: 35
# Token: حوالے, Frequency: 34
# Token: کور, Frequency: 34
# Token: اتفاق, Frequency: 34
# Token: سونے, Frequency: 34
# Token: اسلامی, Frequency: 34
# Token: معاف, Frequency: 34
# Token: گزر, Frequency: 34
# Token: فرشتے, Frequency: 34
# Token: عورتوں, Frequency: 34
# Token: کہانی, Frequency: 34
# Token: چینل, Frequency: 34
# Token: کروانے, Frequency: 34
# Token: سکی, Frequency: 34
# Token: شو, Frequency: 34
# Token: اکتوبر, Frequency: 34
# Token: کیجئے, Frequency: 34
# Token: ہاؤس, Frequency: 34
# Token: آجکل, Frequency: 34
# Token: فقط, Frequency: 34
# Token: دوران, Frequency: 34
# Token: فیک, Frequency: 34
# Token: موجودہ, Frequency: 34
# Token: کےمطابق, Frequency: 34
# Token: لازمی, Frequency: 34
# Token: چھ, Frequency: 34
# Token: مالک, Frequency: 34
# Token: زھرا, Frequency: 34
# Token: ججز, Frequency: 34
# Token: میسج, Frequency: 34
# Token: پڑھے, Frequency: 34
# Token: ہاہاہاہا, Frequency: 34
# Token: 6, Frequency: 33
# Token: نبی, Frequency: 33
# Token: جانتا, Frequency: 33
# Token: انڈین, Frequency: 33
# Token: جمع, Frequency: 33
# Token: علم, Frequency: 33
# Token: پیا, Frequency: 33
# Token: مکس, Frequency: 33
# Token: الخیر, Frequency: 33
# Token: کمپنی, Frequency: 33
# Token: چلتے, Frequency: 33
# Token: پناہ, Frequency: 33
# Token: کمی, Frequency: 33
# Token: بھائ, Frequency: 33
# Token: زیدی, Frequency: 33
# Token: انگلش, Frequency: 33
# Token: مارے, Frequency: 33
# Token: حقیقی, Frequency: 33
# Token: بیچارہ, Frequency: 33
# Token: خواجہ, Frequency: 33
# Token: ضمانت, Frequency: 33
# Token: معاشرے, Frequency: 33
# Token: رائے, Frequency: 33
# Token: ـ, Frequency: 33
# Token: بھائیوں, Frequency: 32
# Token: خرچہ, Frequency: 32
# Token: لائے, Frequency: 32
# Token: دیوار, Frequency: 32
# Token: اتار, Frequency: 32
# Token: کٹھ, Frequency: 32
# Token: منٹ, Frequency: 32
# Token: شدید, Frequency: 32
# Token: آؤ, Frequency: 32
# Token: سامنا, Frequency: 32
# Token: مداخلت, Frequency: 32
# Token: انڈوں, Frequency: 32
# Token: لگانا, Frequency: 32
# Token: ارب, Frequency: 32
# Token: خوف, Frequency: 32
# Token: والو, Frequency: 32
# Token: ھوئی, Frequency: 32
# Token: کیخلاف, Frequency: 32
# Token: کھڑا, Frequency: 32
# Token: شیطان, Frequency: 32
# Token: بلند, Frequency: 32
# Token: سکا, Frequency: 32
# Token: موسم, Frequency: 32
# Token: جانو, Frequency: 32
# Token: شدہ, Frequency: 32
# Token: قتل, Frequency: 32
# Token: حملہ, Frequency: 32
# Token: جاکر, Frequency: 32
# Token: بیوقوف, Frequency: 31
# Token: لکھنا, Frequency: 31
# Token: بدلے, Frequency: 31
# Token: اتحاد, Frequency: 31
# Token: لیول, Frequency: 31
# Token: شاعر, Frequency: 31
# Token: مارا, Frequency: 31
# Token: احتجاج, Frequency: 31
# Token: سلیکٹڈ, Frequency: 31
# Token: نیں, Frequency: 31
# Token: نالائق, Frequency: 31
# Token: ایل, Frequency: 31
# Token: ٹیگ, Frequency: 31
# Token: دروازہ, Frequency: 31
# Token: خوشیاں, Frequency: 31
# Token: افسر, Frequency: 31
# Token: بتانا, Frequency: 31
# Token: مقصد, Frequency: 31
# Token: چلتی, Frequency: 31
# Token: هے, Frequency: 31
# Token: خاموشی, Frequency: 31
# Token: تصویریں, Frequency: 31
# Token: وائرس, Frequency: 31
# Token: نظام, Frequency: 31
# Token: تیس, Frequency: 31
# Token: اٹھ, Frequency: 31
# Token: مہینے, Frequency: 31
# Token: جیالا, Frequency: 31
# Token: ممالک, Frequency: 31
# Token: غ, Frequency: 31
# Token: آئےناں_کنٹینرتے, Frequency: 31
# Token: ناک, Frequency: 30
# Token: آۓ, Frequency: 30
# Token: صافی, Frequency: 30
# Token: معافی, Frequency: 30
# Token: بولے, Frequency: 30
# Token: فلم, Frequency: 30
# Token: دلال, Frequency: 30
# Token: نشہ, Frequency: 30
# Token: عزتی, Frequency: 30
# Token: رحم, Frequency: 30
# Token: فواد, Frequency: 30
# Token: انکار, Frequency: 30
# Token: یقینی, Frequency: 30
# Token: قمر, Frequency: 30
# Token: زمانہ, Frequency: 30
# Token: 30, Frequency: 30
# Token: SindhGovt, Frequency: 30
# Token: پکڑا, Frequency: 30
# Token: ڈبل, Frequency: 30
# Token: بچپن, Frequency: 30
# Token: قیمت, Frequency: 30
# Token: نیب, Frequency: 30
# Token: ملنے, Frequency: 30
# Token: بتائے, Frequency: 30
# Token: اقتدار, Frequency: 30
# Token: ریکارڈ, Frequency: 30
# Token: موڈ, Frequency: 30
# Token: تبدیل, Frequency: 30
# Token: قدم, Frequency: 30
# Token: سسٹم, Frequency: 30
# Token: خواتین, Frequency: 30
# Token: گورے, Frequency: 30
# Token: زہر, Frequency: 30
# Token: تحقیق, Frequency: 30
# Token: سےگزارش, Frequency: 30
# Token: آں, Frequency: 29
# Token: آزاد, Frequency: 29
# Token: ہاہاہاہاہاہا, Frequency: 29
# Token: سیاستدانوں, Frequency: 29
# Token: معاملہ, Frequency: 29
# Token: پایا, Frequency: 29
# Token: ذرائع, Frequency: 29
# Token: سچی, Frequency: 29
# Token: ڈالا, Frequency: 29
# Token: تیر, Frequency: 29
# Token: انداز, Frequency: 29
# Token: کردیں, Frequency: 29
# Token: 7, Frequency: 29
# Token: وعدہ, Frequency: 29
# Token: مہنگا, Frequency: 29
# Token: سیدھا, Frequency: 29
# Token: آٹا600روپےلیٹر, Frequency: 29
# Token: جانی, Frequency: 29
# Token: برائے, Frequency: 29
# Token: انشاء, Frequency: 29
# Token: اغواہ, Frequency: 29
# Token: ناکام, Frequency: 29
# Token: جہاز, Frequency: 29
# Token: فیل, Frequency: 29
# Token: بھاری, Frequency: 29
# Token: __, Frequency: 29
# Token: عوامی, Frequency: 29
# Token: ایمان, Frequency: 29
# Token: چالاک, Frequency: 29
# Token: مال, Frequency: 29
# Token: بھری, Frequency: 29
# Token: رونا, Frequency: 29
# Token: نکلی, Frequency: 29
# Token: سوری, Frequency: 29
# Token: کمائی, Frequency: 29
# Token: اچکزئ, Frequency: 29
# Token: مشہور, Frequency: 29
# Token: پیسہ, Frequency: 29
# Token: درمیان, Frequency: 29
# Token: 75, Frequency: 29
# Token: بٹ, Frequency: 29
# Token: بچ, Frequency: 29
# Token: زور, Frequency: 29
# Token: جنہوں, Frequency: 29
# Token: حجم, Frequency: 29
# Token: مونچھیں, Frequency: 29
# Token: مقامی, Frequency: 29
# Token: محفلسخن, Frequency: 29
# Token: پٹواریوںکیمادرملت, Frequency: 29
# Token: لگائی, Frequency: 28
# Token: سفر, Frequency: 28
# Token: واقعے, Frequency: 28
# Token: 2018, Frequency: 28
# Token: پیر, Frequency: 28
# Token: انکل, Frequency: 28
# Token: امیر, Frequency: 28
# Token: نئ, Frequency: 28
# Token: ثم, Frequency: 28
# Token: سانوں, Frequency: 28
# Token: ملت, Frequency: 28
# Token: کھڑی, Frequency: 28
# Token: ڈرامے, Frequency: 28
# Token: جرنیل, Frequency: 28
# Token: بچا, Frequency: 28
# Token: لگائے, Frequency: 28
# Token: ٹیکس, Frequency: 28
# Token: وعلی, Frequency: 28
# Token: پڑتے, Frequency: 28
# Token: جاے, Frequency: 28
# Token: نکلیں, Frequency: 28
# Token: کرنل, Frequency: 28
# Token: پچاس, Frequency: 28
# Token: عالمی, Frequency: 28
# Token: دفاع, Frequency: 28
# Token: رضی, Frequency: 28
# Token: ہاہاہا, Frequency: 28
# Token: بزدل, Frequency: 28
# Token: پن, Frequency: 28
# Token: ننگی, Frequency: 28
# Token: دیکھنی, Frequency: 28
# Token: شہید, Frequency: 28
# Token: لاکھوں, Frequency: 28
# Token: لمبی, Frequency: 28
# Token: پائی, Frequency: 28
# Token: سالے, Frequency: 28
# Token: اچانک, Frequency: 28
# Token: کھوتے, Frequency: 28
# Token: گاڑی, Frequency: 28
# Token: چاہئیے, Frequency: 28
# Token: غرق, Frequency: 28
# Token: اہم, Frequency: 28
# Token: ڈالر, Frequency: 28
# Token: کروائے, Frequency: 28
# Token: دان, Frequency: 28
# Token: سچا, Frequency: 28
# Token: احترام, Frequency: 28
# Token: الہی, Frequency: 28
# Token: بال, Frequency: 28
# Token: تجارت, Frequency: 28
# Token: زخم, Frequency: 27
# Token: ہورہا, Frequency: 27
# Token: بیشک, Frequency: 27
# Token: عزیز, Frequency: 27
# Token: ویلکم, Frequency: 27
# Token: بلی, Frequency: 27
# Token: لیگی, Frequency: 27
# Token: جوانی, Frequency: 27
# Token: جتنے, Frequency: 27
# Token: بنانا, Frequency: 27
# Token: اظہار, Frequency: 27
# Token: شکار, Frequency: 27
# Token: عاشق, Frequency: 27
# Token: کوئی_مرادعلی_شاہ_سےپوچھے, Frequency: 27
# Token: ھونے, Frequency: 27
# Token: ٹکے, Frequency: 27
# Token: درویش, Frequency: 27
# Token: ند, Frequency: 27
# Token: زلیل, Frequency: 27
# Token: I, Frequency: 27
# Token: بارش, Frequency: 27
# Token: سونپ, Frequency: 27
# Token: سبق, Frequency: 27
# Token: مریض, Frequency: 27
# Token: وینا, Frequency: 27
# Token: جھوٹی, Frequency: 27
# Token: انگور, Frequency: 27
# Token: ٹک, Frequency: 27
# Token: گۓ, Frequency: 27
# Token: محمود, Frequency: 27
# Token: جوتے, Frequency: 27
# Token: بم, Frequency: 27
# Token: فالوورز, Frequency: 27
# Token: بدنام, Frequency: 27
# Token: وزارت, Frequency: 27
# Token: جیب, Frequency: 27
# Token: رک, Frequency: 27
# Token: طلب, Frequency: 27
# Token: دورہ, Frequency: 27
# Token: انگلی, Frequency: 27
# Token: عالم, Frequency: 27
# Token: 50, Frequency: 27
# Token: حوصلہ, Frequency: 27
# Token: استاد, Frequency: 27
# Token: لڑکے, Frequency: 27
# Token: دینگے, Frequency: 27
# Token: کیساتھ, Frequency: 27
# Token: خط, Frequency: 27
# Token: ذاتی, Frequency: 27
# Token: بنتی, Frequency: 27
# Token: یافتہ, Frequency: 27
# Token: ﮨﮯ, Frequency: 27
# Token: ہوئ, Frequency: 27
# Token: جسم, Frequency: 27
# Token: لگنے, Frequency: 27
# Token: pti, Frequency: 27
# Token: سکیں, Frequency: 27
# Token: اقسام, Frequency: 27
# Token: اگرکوئی, Frequency: 27
# Token: سمجھتاہےکہ, Frequency: 27
# Token: ادایئگیوں, Frequency: 27
# Token: کےتوازن, Frequency: 27
# Token: کاخسارہ, Frequency: 27
# Token: اورجہازی, Frequency: 27
# Token: کاغیرملکی, Frequency: 27
# Token: جیسےمسائل, Frequency: 27
# Token: چائےکی, Frequency: 27
# Token: پیالیوں, Frequency: 27
# Token: سےدرست, Frequency: 27
# Token: کئےجاسکتےہیں, Frequency: 27
# Token: توایک, Frequency: 27
# Token: ضرب, Frequency: 27
# Token: المثل, Frequency: 27
# Token: مردےکی, Frequency: 27
# Token: مونڈے, Frequency: 27
# Token: سےجنازےکابوجھ, Frequency: 27
# Token: ة, Frequency: 26
# Token: ناممکن, Frequency: 26
# Token: سکو, Frequency: 26
# Token: لگدا, Frequency: 26
# Token: چوک, Frequency: 26
# Token: اصلی, Frequency: 26
# Token: خور, Frequency: 26
# Token: پتلی, Frequency: 26
# Token: پرچی, Frequency: 26
# Token: آرہے, Frequency: 26
# Token: لاک, Frequency: 26
# Token: روشنی, Frequency: 26
# Token: ٹینشن, Frequency: 26
# Token: وضاحت, Frequency: 26
# Token: جوان, Frequency: 26
# Token: مارشل, Frequency: 26
# Token: خرید, Frequency: 26
# Token: چھین, Frequency: 26
# Token: گیند, Frequency: 26
# Token: با, Frequency: 26
# Token: ہزاروں, Frequency: 26
# Token: احسن, Frequency: 26
# Token: کاروبار, Frequency: 26
# Token: لگائیں, Frequency: 26
# Token: جیالے, Frequency: 26
# Token: جاوید, Frequency: 26
# Token: مہمان, Frequency: 26
# Token: باندھ, Frequency: 26
# Token: شعر, Frequency: 26
# Token: وزیراعلی, Frequency: 26
# Token: غصے, Frequency: 26
# Token: اپڈیٹ, Frequency: 26
# Token: ٹوئیٹ, Frequency: 26
# Token: وے, Frequency: 26
# Token: بلوچستان, Frequency: 26
# Token: اٹھایا, Frequency: 26
# Token: کیو, Frequency: 26
# Token: مہنگی, Frequency: 26
# Token: پرانا, Frequency: 26
# Token: فوج_ہے_تو_پاکستان_ہے, Frequency: 26
# Token: سمیت, Frequency: 26
# Token: مرغی, Frequency: 26
# Token: گندی, Frequency: 26
# Token: ہوۓ, Frequency: 26
# Token: گند, Frequency: 26
# Token: یونیورسٹی, Frequency: 26
# Token: صدر, Frequency: 26
# Token: کھل, Frequency: 26
# Token: بل, Frequency: 26
# Token: الھم, Frequency: 26
# Token: الرحمان, Frequency: 26
# Token: جنہیں, Frequency: 25
# Token: دروازے, Frequency: 25
# Token: الحمدللہ, Frequency: 25
# Token: داخل, Frequency: 25
# Token: کامیاب, Frequency: 25
# Token: نکے, Frequency: 25
# Token: ساب, Frequency: 25
# Token: کریڈٹ, Frequency: 25
# Token: لڑکا, Frequency: 25
# Token: کالج, Frequency: 25
# Token: بیمار, Frequency: 25
# Token: توہین, Frequency: 25
# Token: محکمہ, Frequency: 25
# Token: دلوں, Frequency: 25
# Token: ام, Frequency: 25
# Token: کرسی, Frequency: 25
# Token: کپ, Frequency: 25
# Token: تمھارے, Frequency: 25
# Token: می, Frequency: 25
# Token: اچ, Frequency: 25
# Token: چھوڑو, Frequency: 25
# Token: لائق, Frequency: 25
# Token: نااہل, Frequency: 25
# Token: سمجھتا, Frequency: 25
# Token: پاؤں, Frequency: 25
# Token: نمبر1, Frequency: 25
# Token: رخصت, Frequency: 25
# Token: عدالت, Frequency: 25
# Token: بینظیر, Frequency: 25
# Token: لله, Frequency: 25
# Token: چھاپہ, Frequency: 25
# Token: نھی, Frequency: 25
# Token: کھلاڑی, Frequency: 25
# Token: کوٹ, Frequency: 25
# Token: محتاج, Frequency: 25
# Token: بیڑا, Frequency: 25
# Token: ڈوب, Frequency: 25
# Token: جانور, Frequency: 25
# Token: اعتبار, Frequency: 24
# Token: گولیاں, Frequency: 24
# Token: حضور, Frequency: 24
# Token: زبردستی, Frequency: 24
# Token: تنخواہ, Frequency: 24
# Token: طیارہ, Frequency: 24
# Token: فتح, Frequency: 24
# Token: بجے, Frequency: 24
# Token: خبریں, Frequency: 24
# Token: پلے, Frequency: 24
# Token: حیرت, Frequency: 24
# Token: ایمانداری, Frequency: 24
# Token: درخواستیں, Frequency: 24
# Token: مفت, Frequency: 24
# Token: کدھر, Frequency: 24
# Token: فرض, Frequency: 24
# Token: چول, Frequency: 24
# Token: بنتے, Frequency: 24
# Token: وفاقی, Frequency: 24
# Token: الس, Frequency: 24
# Token: لائک, Frequency: 24
# Token: پنسل, Frequency: 24
# Token: لکهو, Frequency: 24
# Token: ربڑ, Frequency: 24
# Token: کریم, Frequency: 24
# Token: تھک, Frequency: 24
# Token: لاء, Frequency: 24
# Token: مہربانی, Frequency: 24
# Token: کھ, Frequency: 24
# Token: رینجر, Frequency: 24
# Token: پھیر, Frequency: 24
# Token: سمجھایا, Frequency: 24
# Token: گھبرانا, Frequency: 24
# Token: مبشر, Frequency: 24
# Token: اکاونٹ, Frequency: 24
# Token: ملکی, Frequency: 24
# Token: ہوکر, Frequency: 24
# Token: فیض, Frequency: 24
# Token: امن, Frequency: 24
# Token: بھرپور, Frequency: 24
# Token: ترے, Frequency: 24
# Token: بنائیں, Frequency: 24
# Token: آگئی, Frequency: 24
# Token: جعلی, Frequency: 24
# Token: کمیٹی, Frequency: 24
# Token: چیزیں, Frequency: 24
# Token: دین, Frequency: 24
# Token: دہشت, Frequency: 24
# Token: عامر, Frequency: 24
# Token: مسلمان, Frequency: 24
# Token: لاجواب, Frequency: 24
# Token: تجربہ, Frequency: 24
# Token: هو, Frequency: 24
# Token: خالی, Frequency: 24
# Token: معیشت, Frequency: 24
# Token: منتخب, Frequency: 24
# Token: فیملی, Frequency: 24
# Token: آبادی, Frequency: 24
# Token: کالے, Frequency: 24
# Token: امان, Frequency: 24
# Token: سول, Frequency: 24
# Token: تعداد, Frequency: 24
# Token: رکھتا, Frequency: 24
# Token: اول, Frequency: 24
# Token: سمت, Frequency: 24
# Token: العزت, Frequency: 24
# Token: بھارتی, Frequency: 24
# Token: واسطے, Frequency: 24
# Token: ARY, Frequency: 24
# Token: ذکر, Frequency: 24
# Token: زمہ, Frequency: 23
# Token: ہویا, Frequency: 23
# Token: سالہ, Frequency: 23
# Token: مولا, Frequency: 23
# Token: اوئے, Frequency: 23
# Token: مصطفی, Frequency: 23
# Token: انسانوں, Frequency: 23
# Token: بهی, Frequency: 23
# Token: IGSindh, Frequency: 23
# Token: عرب, Frequency: 23
# Token: محض, Frequency: 23
# Token: کھسرے, Frequency: 23
# Token: مک, Frequency: 23
# Token: پارٹیوں, Frequency: 23
# Token: مے, Frequency: 23
# Token: واقعہ, Frequency: 23
# Token: آئندہ, Frequency: 23
# Token: بچی, Frequency: 23
# Token: خیرا, Frequency: 23
# Token: ظاہر, Frequency: 23
# Token: الزامات, Frequency: 23
# Token: انھیں, Frequency: 23
# Token: پوچھے, Frequency: 23
# Token: بتاؤ, Frequency: 23
# Token: غلام, Frequency: 23
# Token: گورنر, Frequency: 23
# Token: بنائی, Frequency: 23
# Token: حاضر, Frequency: 23
# Token: بجلی, Frequency: 23
# Token: ڈیلیٹ, Frequency: 23
# Token: انا, Frequency: 23
# Token: شان, Frequency: 23
# Token: کھلا, Frequency: 23
# Token: منزل, Frequency: 23
# Token: چاول, Frequency: 23
# Token: گاؤں, Frequency: 23
# Token: ذلت, Frequency: 23
# Token: غریبوں, Frequency: 23
# Token: محبوب, Frequency: 23
# Token: ملیں, Frequency: 23
# Token: ابے, Frequency: 23
# Token: چین, Frequency: 23
# Token: ہمت, Frequency: 23
# Token: جرم, Frequency: 23
# Token: ما, Frequency: 23
# Token: لکھی, Frequency: 23
# Token: سبحان, Frequency: 23
# Token: عباسی, Frequency: 23
# Token: ریا, Frequency: 23
# Token: بنائے, Frequency: 23
# Token: مناسب, Frequency: 23
# Token: لفافوں_کی_فیک_نیوز, Frequency: 23
# Token: ضائع, Frequency: 23
# Token: نمک, Frequency: 23
# Token: باوجود, Frequency: 23
# Token: بنو, Frequency: 23
# Token: دعاؤں, Frequency: 23
# Token: غرور, Frequency: 23
# Token: چھوٹا, Frequency: 23
# Token: مشرف, Frequency: 23
# Token: واسطہ, Frequency: 23
# Token: عید, Frequency: 23
# Token: چیخیں, Frequency: 23
# Token: شاہد, Frequency: 23
# Token: ہراساں, Frequency: 23
# Token: ویلڈن, Frequency: 22
# Token: کیتی, Frequency: 22
# Token: ایتھے, Frequency: 22
# Token: گن, Frequency: 22
# Token: لوگو, Frequency: 22
# Token: خدمت, Frequency: 22
# Token: فیاض, Frequency: 22
# Token: طاقت, Frequency: 22
# Token: برائی, Frequency: 22
# Token: کھو, Frequency: 22
# Token: ادارے, Frequency: 22
# Token: سیر, Frequency: 22
# Token: مسٹر, Frequency: 22
# Token: ظالم, Frequency: 22
# ...
# Token: ٹوٹتے, Frequency: 1
# Token: مناتا, Frequency: 1
# Token: الجھنا, Frequency: 1
# Token: MENTAL, Frequency: 1
# Token: ظالماں, Frequency: 1
# Token: سباں, Frequency: 1
# Token: FareedZakaria, Frequency: 1
# Token: CNN, Frequency: 1
# Token: cnni, Frequency: 1
# Token: ہنٹریو, Frequency: 1
# Token: compact, Frequency: 1
# Token: AngryBird5120, Frequency: 1
# Token: kharoospagal, Frequency: 1
# Token: کھیلو, Frequency: 1
# Token: استمال, Frequency: 1
# Token: تنزو, Frequency: 1
# Token: پالتوں, Frequency: 1
# Token: tA5ASPuYZG, Frequency: 1
# Token: realikramnaseem, Frequency: 1
# Token: مردا, Frequency: 1
# Token: UbFNJO5wGp, Frequency: 1
# Token: ShanilaSikandar, Frequency: 1
# Token: NoorulArfeenSid, Frequency: 1
# Token: TahirMughalPml1, Frequency: 1
# Token: نمی, Frequency: 1
# Token: ٹھٹھا, Frequency: 1
# Token: ساہیڈ, Frequency: 1
# Token: سٹیدیم, Frequency: 1
# Token: کراوڈ, Frequency: 1
# Token: کمنگ, Frequency: 1
# Token: Ali_syed3, Frequency: 1
# Token: AhmadWaleed, Frequency: 1
# Token: مسخروں, Frequency: 1
# Token: نکدے, Frequency: 1
# Token: ہےend, Frequency: 1
# Token: گاہےبگاہے, Frequency: 1
# Token: استعارہ, Frequency: 1
# Token: زدعام, Frequency: 1
# Token: معاشرتی, Frequency: 1
# Token: روابط, Frequency: 1
# Token: jeera_007, Frequency: 1
# Token: جپھی, Frequency: 1
# Token: MSvsLQ, Frequency: 1
# Token: PSLFriday, Frequency: 1
# Token: 4eJK7ssEi4, Frequency: 1
# Token: گھٹتے, Frequency: 1
# Token: VqE5ju8Zg2, Frequency: 1
# Token: unidentified008, Frequency: 1
# Token: کبیرہ, Frequency: 1
# Token: ہاہہاہا, Frequency: 1
# Token: nad25nc, Frequency: 1
# Token: HinaIkhan, Frequency: 1
# Token: ہیں۰, Frequency: 1
# Token: umarfar53474973, Frequency: 1
# Token: صاحپ, Frequency: 1
# Token: شیرجیسے, Frequency: 1
# Token: آجاونگی, Frequency: 1
# Token: AD_Shakeeb, Frequency: 1
# Token: یوتھیاز, Frequency: 1
# Token: edited, Frequency: 1
# Token: IYc5NfIihn, Frequency: 1
# Token: Msk_Salloo, Frequency: 1
# Token: سرکل, Frequency: 1
# Token: سراہ, Frequency: 1
# Token: چمکتے, Frequency: 1
# Token: سٹی, Frequency: 1
# Token: پریزیڈنٹ, Frequency: 1
# Token: اڑنے, Frequency: 1
# Token: 11بجے, Frequency: 1
# Token: سرمایہ_ادب, Frequency: 1
# Token: سانولے, Frequency: 1
# Token: آکڑ, Frequency: 1
# Token: 7فروری2022کو, Frequency: 1
# Token: SenPervaizRd, Frequency: 1
# Token: مرچکا, Frequency: 1
# Token: مظاہرے, Frequency: 1
# Token: لغام, Frequency: 1
# Token: گھٹیہ, Frequency: 1
# Token: ٹیسی, Frequency: 1
# Token: سواں, Frequency: 1
# Token: کھسمانو, Frequency: 1
# Token: راغب, Frequency: 1
# Token: Lokiodin0x, Frequency: 1
# Token: الیاس, Frequency: 1
# Token: ٹرینگ, Frequency: 1
# Token: Kuri_punjabi1, Frequency: 1
# Token: کراتیں, Frequency: 1
# Token: پروگراموں, Frequency: 1
# Token: سلیپ, Frequency: 1
# Token: اسٹک, Frequency: 1
# Token: متروک, Frequency: 1
# Token: لہری, Frequency: 1
# Token: اسٹارز, Frequency: 1
# Token: جمشید, Frequency: 1
# Token: انصاری, Frequency: 1
# Token: بہروز, Frequency: 1
# Token: سبزواری, Frequency: 1
# Token: narcissistvibes, Frequency: 1
# Token: موضوعات, Frequency: 1
# Token: باریکی, Frequency: 1
# Token: ہیروز, Frequency: 1
# Token: مافوق, Frequency: 1
# Token: الفطرت, Frequency: 1
# Token: کرداروں, Frequency: 1
# Token: چوہئ, Frequency: 1
# Token: سڑکے, Frequency: 1
# Token: جاہلیت, Frequency: 1
# Token: geodigitalvideo, Frequency: 1
# Token: GJRPDn5DdJ, Frequency: 1
# Token: مطابقت, Frequency: 1
# Token: IAsvwHEZpD, Frequency: 1
# Token: شریان, Frequency: 1
# Token: فشار, Frequency: 1
# Token: آگہی, Frequency: 1
# Token: تاوان, Frequency: 1
# Token: Mian_MUR, Frequency: 1
# Token: SADEyes200, Frequency: 1
# Token: شچ, Frequency: 1
# Token: SenDrAbdulKarim, Frequency: 1
# Token: NjqACsCczA, Frequency: 1
# Token: TtMZ5j1AgP, Frequency: 1
# Token: rababsheikh1, Frequency: 1
# Token: جھوڑی, Frequency: 1
# Token: MuneebaMominZA, Frequency: 1
# Token: دوجیاں, Frequency: 1
# Token: SadafR12, Frequency: 1
# Token: بخالت, Frequency: 1
# Token: مترادف, Frequency: 1
# Token: اپنی_زبان_اردو, Frequency: 1
# Token: C, Frequency: 1
# Token: Baig25239209, Frequency: 1
# Token: ضوریز, Frequency: 1
# Token: SaniaKhattak9, Frequency: 1
# Token: پنجو, Frequency: 1
# Token: چھوکری, Frequency: 1
# Token: SumoRizvi, Frequency: 1
# Token: بکھیرنا, Frequency: 1
# Token: بڑھائے, Frequency: 1
# Token: M_Usman_Khokhar, Frequency: 1
# Token: انہتائی, Frequency: 1
# Token: جارحانہ, Frequency: 1
# Token: متعدل, Frequency: 1
# Token: آص, Frequency: 1
# Token: تکو, Frequency: 1
# Token: چھوں, Frequency: 1
# Token: _سی, Frequency: 1
# Token: لواحقین, Frequency: 1
# Token: صنعت, Frequency: 1
# Token: تعصبات, Frequency: 1
# Token: ej974ZpsE6, Frequency: 1
# Token: سانی, Frequency: 1
# Token: 2022, Frequency: 1
# Token: sirsirajshah, Frequency: 1
# Token: اض, Frequency: 1
# Token: غارت, Frequency: 1
# Token: سیچوئشن, Frequency: 1
# Token: فیڈرل, Frequency: 1
# Token: تمن, Frequency: 1
# Token: اؤں, Frequency: 1
# Token: مژدہ, Frequency: 1
# Token: خدوخال, Frequency: 1
# Token: ٹاو, Frequency: 1
# Token: پچھ, Frequency: 1
# Token: یرو, Frequency: 1
# Token: کھاٸی, Frequency: 1
# Token: گندمی, Frequency: 1
# Token: براوں, Frequency: 1
# Token: داریاں, Frequency: 1
# Token: بھونپو, Frequency: 1
# Token: متنفر, Frequency: 1
# Token: بوٹوں, Frequency: 1
# Token: کپڑا, Frequency: 1
# Token: زہے, Frequency: 1
# Token: شکرہے, Frequency: 1
# Token: بورنگ, Frequency: 1
# Token: دولاکھ, Frequency: 1
# Token: سرشار, Frequency: 1
# Token: جانبازوں, Frequency: 1
# Token: ٹخنوں, Frequency: 1
# Token: یوتھئیوں, Frequency: 1
# Token: سنبھل, Frequency: 1
# Token: عقابوں, Frequency: 1
# Token: کلیجہ, Frequency: 1
# Token: مادام, Frequency: 1
# Token: گھمبیر, Frequency: 1
# Token: 45k, Frequency: 1
# Token: تھوکیں, Frequency: 1
# Token: رئیسانی, Frequency: 1
# Token: کانفرنسز, Frequency: 1
# Token: کرنیوالی, Frequency: 1
# Token: نکھار, Frequency: 1
# Token: optimistic, Frequency: 1
# Token: ہیدائش, Frequency: 1
# Token: چڈی, Frequency: 1
# Token: معلوماتی_ٹویٹ, Frequency: 1
# Token: بینے, Frequency: 1
# Token: شکت, Frequency: 1
# Token: کسموں, Frequency: 1
# Token: بیبگر, Frequency: 1
# Token: وت, Frequency: 1
# Token: لاپ, Frequency: 1
# Token: شوھاز, Frequency: 1
# Token: دانکہ, Frequency: 1
# Token: اشانء, Frequency: 1
# Token: دء, Frequency: 1
# Token: گژن, Frequency: 1
# Token: ایت, Frequency: 1
# Token: معاش, Frequency: 1
# Token: بگلیں, Frequency: 1
# Token: بلاٶ, Frequency: 1
# Token: کسےدرجنگ, Frequency: 1
# Token: هرروزشهـیدمیشہ, Frequency: 1
# Token: زمینیں, Frequency: 1
# Token: ٹائون, Frequency: 1
# Token: اورسیدھے, Frequency: 1
# Token: مطلبی, Frequency: 1
# Token: اسےگلے, Frequency: 1
# Token: 𝖅𝖎𝖒𝖆𝖑__𝖏𝖚𝖙𝖙, Frequency: 1
# Token: لاقات, Frequency: 1
# Token: بیچھنے, Frequency: 1
# Token: دردناک, Frequency: 1
# Token: ڈیسکس, Frequency: 1
# Token: ہورہیں, Frequency: 1
# Token: still, Frequency: 1
# Token: hope, Frequency: 1
# Token: Allah, Frequency: 1
# Token: Almighty, Frequency: 1
# Token: ناساں, Frequency: 1
# Token: دینیاں, Frequency: 1
# Token: بسمل, Frequency: 1
# Token: ویرانہ, Frequency: 1
# Token: دھنے, Frequency: 1
# Token: واد, Frequency: 1
# Token: تزلیل, Frequency: 1
# Token: پلایا, Frequency: 1
# Token: ٹھس, Frequency: 1
# Token: پاؤنڈ, Frequency: 1
# Token: گجرانوالا, Frequency: 1
# Token: کھاڑ, Frequency: 1
# Token: saeedkabir851, Frequency: 1
# Token: فحش, Frequency: 1
# Token: کامیڈینز, Frequency: 1
# Token: گردانے, Frequency: 1
# Token: retweet, Frequency: 1
# Token: خاتین, Frequency: 1
# Token: لکھوایا, Frequency: 1
# Token: ماغ, Frequency: 1
# Token: moona_sikander, Frequency: 1
# Token: irshadkhaaan, Frequency: 1
# Token: کومک, Frequency: 1
# Token: رائیٹر, Frequency: 1
# Token: سرخیل, Frequency: 1
# Token: پیراسائٹ, Frequency: 1
# Token: چوسےاور, Frequency: 1
# Token: اردو_طنز_و_مزاح, Frequency: 1
# Token: سلمان_جٹ_رایٹس, Frequency: 1
# Token: پارلیمنٹرین, Frequency: 1
# Token: بہتریں, Frequency: 1
# Token: خطابت, Frequency: 1
# Token: ہنچ, Frequency: 1
# Token: اسلام_علیکم, Frequency: 1
# Token: MuftiMufta, Frequency: 1
# Token: سمال, Frequency: 1
# Token: کراکری, Frequency: 1
# Token: پہانڈا, Frequency: 1
# Token: MahiJutt_, Frequency: 1
# Token: تھانیدارنی, Frequency: 1
# Token: gulk3990, Frequency: 1
# Token: i8R5ldTgib, Frequency: 1
# Token: ہیں__وقت, Frequency: 1
# Token: سنادیں, Frequency: 1
# Token: usman_sky143, Frequency: 1
# Token: قانونا, Frequency: 1
# Token: Mlk5A, Frequency: 1
# Token: zehraa_masoom, Frequency: 1
# Token: MehrifLAZ, Frequency: 1
# Token: جوکس, Frequency: 1
# Token: ToWhomItMayConcern, Frequency: 1
# Token: candyguy08, Frequency: 1
# Token: ManiJee2022122, Frequency: 1
# Token: Ahmed__Nadeem, Frequency: 1
# Token: چلینج, Frequency: 1
# Token: سیکھاتا, Frequency: 1
# Token: ہوئیے, Frequency: 1
# Token: sara_malkani_, Frequency: 1
# Token: سرویا, Frequency: 1
# Token: 1SamPk, Frequency: 1
# Token: ٹیکنے, Frequency: 1
# Token: لگادیا, Frequency: 1
# Token: tB54NCwDgc, Frequency: 1
# Token: خصوصیات, Frequency: 1
# Token: nafees66, Frequency: 1
# Token: but, Frequency: 1
# Token: enjoyed, Frequency: 1
# Token: کھوڈے, Frequency: 1
# Token: کبھاڑ, Frequency: 1
# Token: اودہی, Frequency: 1
# Token: اکھ, Frequency: 1
# Token: کیویں, Frequency: 1
# Token: ZohaibChinu, Frequency: 1
# Token: تراشیوں, Frequency: 1
# Token: دھلائ, Frequency: 1
# Token: ریپلے, Frequency: 1
# Token: علي, Frequency: 1
# Token: مصائ, Frequency: 1
# Token: أن, Frequency: 1
# Token: الأيام, Frequency: 1
# Token: ليالي, Frequency: 1
# Token: مصائب, Frequency: 1
# Token: علیہا, Frequency: 1
# Token: CPEC, Frequency: 1
# Token: رفتاری, Frequency: 1
# Token: آسٹرلیا, Frequency: 1
# Token: جزیرہ, Frequency: 1
# Token: الرشید, Frequency: 1
# Token: بدنیتو, Frequency: 1
# Token: دشمنو, Frequency: 1
# Token: غدارو, Frequency: 1
# Token: کرپٹو, Frequency: 1
# Token: پڑھنیں, Frequency: 1
# Token: طب, Frequency: 1
# Token: للی, Frequency: 1
# Token: ھوس, Frequency: 1
# Token: نکرئے, Frequency: 1
# Token: Appreciated, Frequency: 1
# Token: 11جھنڈے, Frequency: 1
# Token: زیست, Frequency: 1
# Token: اتباف_ابرک, Frequency: 1
# Token: عرصےسے, Frequency: 1
# Token: بٹھایا, Frequency: 1
# Token: ShibliFaraz, Frequency: 1
# Token: ششٹم, Frequency: 1
# Token: حرامزادے, Frequency: 1
# Token: ایسانہ, Frequency: 1
# Token: کدووووو, Frequency: 1
# Token: state, Frequency: 1
# Token: اپنڑی, Frequency: 1
# Token: ٹنڈو, Frequency: 1
# Token: الہیار, Frequency: 1
# Token: چاولوں, Frequency: 1
# Token: دبی, Frequency: 1
# Token: ارفان, Frequency: 1
# Token: ماخوذ, Frequency: 1
# Token: حکایات, Frequency: 1
# Token: افروغ, Frequency: 1
# Token: ویگو, Frequency: 1
# Token: مبین, Frequency: 1
# Token: کئى, Frequency: 1
# Token: ڈى, Frequency: 1
# Token: لاحول, Frequency: 1
# Token: قوۃ, Frequency: 1
# Token: 60روپے, Frequency: 1
# Token: 130, Frequency: 1
# Token: بےغیرتی, Frequency: 1
# Token: شرمی___تیرا, Frequency: 1
# Token: ٸ, Frequency: 1
# Token: آسکی, Frequency: 1
# Token: بچھڑا, Frequency: 1
# Token: وٹانا, Frequency: 1
# Token: لےچکا, Frequency: 1
# Token: ہےجسکا, Frequency: 1
# Token: نواز_بھائی_لندن_والے, Frequency: 1
# Token: کھوٹی, Frequency: 1
# Token: انائیں, Frequency: 1
# Token: لیٹرے, Frequency: 1
# Token: گرلز, Frequency: 1
# Token: کروادیتی, Frequency: 1
# Token: جلتابالکل, Frequency: 1
# Token: اچھےکو, Frequency: 1
# Token: اكھيا, Frequency: 1
# Token: بيوى, Frequency: 1
# Token: سےPDMوجود, Frequency: 1
# Token: للکارے, Frequency: 1
# Token: کیلوں, Frequency: 1
# Token: چڑاں, Frequency: 1
# Token: کنواروں, Frequency: 1
# Token: گھومنے, Frequency: 1
# Token: القتل, Frequency: 1
# Token: تمنائیں, Frequency: 1
# Token: ٹوکرز, Frequency: 1
# Token: بوبو, Frequency: 1
# Token: بیخرمتی, Frequency: 1
# Token: اوت, Frequency: 1
# Token: زکات, Frequency: 1
# Token: بنارہا, Frequency: 1
# Token: قصیدے, Frequency: 1
# Token: لاڈلا, Frequency: 1
# Token: چتھر, Frequency: 1
# Token: اونترا, Frequency: 1
# Token: مضحکہ, Frequency: 1
# Token: موزانہ, Frequency: 1
# Token: سکوپ, Frequency: 1
# Token: آر_جے, Frequency: 1
# Token: نمونوں, Frequency: 1
# Token: صنوبر, Frequency: 1
# Token: سپورٹروں, Frequency: 1
# Token: پٹوایوں, Frequency: 1
# Token: لئےاطلاع, Frequency: 1
# Token: پڑگئیں, Frequency: 1
# Token: کانگرنس, Frequency: 1
# Token: کیعبد, Frequency: 1
# Token: ریکورئی, Frequency: 1
# Token: نقیب, Frequency: 1
# Token: پریگنٹ, Frequency: 1
# Token: کسکا, Frequency: 1
# Token: 𝕫𝕚𝕞𝕒𝕝__𝕛𝕦𝕥𝕥, Frequency: 1
# Token: ہییییییییییییییییں, Frequency: 1
# Token: چٹ, Frequency: 1
# Token: نوازشرہف, Frequency: 1
# Token: پجاواں, Frequency: 1
# Token: شٹام, Frequency: 1
# Token: Top, Frequency: 1
# Token: آرم, Frequency: 1
# Token: سمیٹا, Frequency: 1
# Token: ٹیویٹر, Frequency: 1
# Token: کو1بات, Frequency: 1
# Token: بتادیجئے, Frequency: 1
# Token: 1پھسڈی, Frequency: 1
# Token: چندلفظوں, Frequency: 1
# Token: کوادب, Frequency: 1
# Token: کےزمرے, Frequency: 1
# Token: روکھا, Frequency: 1
# Token: مجب, Frequency: 1
# Token: PAKISTANZINDABAD, Frequency: 1
# Token: PAKISTAN, Frequency: 1
# Token: رازوں, Frequency: 1
# Token: surely, Frequency: 1
# Token: Faraz, Frequency: 1
# Token: رلی, Frequency: 1
# Token: بکلم, Frequency: 1
# Token: خانقاہ, Frequency: 1
# Token: ڈوگراں, Frequency: 1
# Token: واااااہ, Frequency: 1
# Token: ________محبت, Frequency: 1
# Token: چھپوائں, Frequency: 1
# Token: کیدی, Frequency: 1
# Token: ھکومت, Frequency: 1
# Token: بناٸیں, Frequency: 1
# Token: پراٸم, Frequency: 1
# Token: یرورت, Frequency: 1
# Token: سمجھائیں, Frequency: 1
# Token: کٹھکھٹانا, Frequency: 1
# Token: اٹینشن, Frequency: 1
# Token: ResPecT, Frequency: 1
# Token: BeTTer, Frequency: 1
# Token: ThAn, Frequency: 1
# Token: FaKe, Frequency: 1
# Token: VE, Frequency: 1
# Token: ہےاورلڑکیوں, Frequency: 1
# Token: تپنا, Frequency: 1
# Token: فوٹوگرافی, Frequency: 1
# Token: شرطیں, Frequency: 1
# Token: گنبد, Frequency: 1
# Token: پر_, Frequency: 1
# Token: احتـــــرام, Frequency: 1
# Token: گناه, Frequency: 1
# Token: ہااائے, Frequency: 1
# Token: بتتمیزی, Frequency: 1
# Token: پہنچاۓ, Frequency: 1
# Token: سینگ, Frequency: 1
# Token: کیمسٹری, Frequency: 1
# Token: سپلینگ, Frequency: 1
# Token: کمزورکرنے, Frequency: 1
# Token: ﺑﺎﻗﯽ, Frequency: 1
# Token: ﺑﺎﺗﯿﮟ, Frequency: 1
# Token: ﭼﻬﻮﮌﻭ, Frequency: 1
# Token: ﻣﺴﮑﺮﺍﺗﯽ, Frequency: 1
# Token: ﺑﮍﯼ, Frequency: 1
# Token: ﺍﺩﺍ, Frequency: 1
# Token: ﻫو, Frequency: 1
# Token: لڑکھڑانے, Frequency: 1
# Token: پتلونیں, Frequency: 1
# Token: ہےاس, Frequency: 1
# Token: وہ_پوچھنا, Frequency: 1
# Token: میرے_دماغ, Frequency: 1
# Token: اکاوٸنٹ, Frequency: 1
# Token: __H__W__B__06, Frequency: 1
# Token: مزدوروں, Frequency: 1
# Token: اجرت, Frequency: 1
# Token: pro, Frequency: 1
# Token: labor, Frequency: 1
# Token: pay, Frequency: 1
# Token: ہماراایوریج, Frequency: 1
# Token: پچھلےکافی, Frequency: 1
# Token: سےسردیوں, Frequency: 1
# Token: میں7, Frequency: 1
# Token: 9ہزاراورگرمیوں, Frequency: 1
# Token: میں۳۰سے۴۵ہزارکے, Frequency: 1
# Token: ہےکیونکہACذیادہ, Frequency: 1
# Token: اورگرمی, Frequency: 1
# Token: کےباعث, Frequency: 1
# Token: مہمانداری, Frequency: 1
# Token: اگر۲سال, Frequency: 1
# Token: کاموازناکروں, Frequency: 1
# Token: تویونٹ, Frequency: 1
# Token: ٹویونٹ, Frequency: 1
# Token: تھوڑاہی, Frequency: 1
# Token: آیاہے, Frequency: 1
# Token: کوجمع, Frequency: 1
# Token: تواب, Frequency: 1
# Token: تک۲۰۱۸کا۴۰, Frequency: 1
# Token: ہزاروالا, Frequency: 1
# Token: 5لاکھ, Frequency: 1
# Token: ہوجاناچاہیےتھا, Frequency: 1
# Token: ڈھیروں, Frequency: 1
# Token: چاکری, Frequency: 1
# Token: ماسوا, Frequency: 1
# Token: جگ, Frequency: 1
# Token: ہنسائی, Frequency: 1
# Token: تگنی, Frequency: 1
# Token: ذلیلوں, Frequency: 1
# Token: معانی, Frequency: 1
# Token: یہان, Frequency: 1
# Token: انڈیں, Frequency: 1
# Token: ٹرانسلیٹ, Frequency: 1
# Token: طرفسے, Frequency: 1
# Token: ہےکا, Frequency: 1
# Token: صیغہ, Frequency: 1
# Token: برسٹ, Frequency: 1
# Token: ماریا, Frequency: 1
# Token: دیکنھے, Frequency: 1
# Token: شافعی, Frequency: 1
# Token: ریتویت, Frequency: 1
# Token: سمع, Frequency: 1
# Token: کرسیاں, Frequency: 1
# Token: پائیے, Frequency: 1
# Token: نہائیے, Frequency: 1
# Token: ڈیسٹنس, Frequency: 1
# Token: سائن, Frequency: 1
# Token: سلوایا, Frequency: 1
# Token: راکڈ, Frequency: 1
# Token: استثنا, Frequency: 1
# Token: جعلسازوں, Frequency: 1
# Token: کیلبری, Frequency: 1
# Token: سنڌي, Frequency: 1
# Token: تبسم, Frequency: 1
# Token: چبڑ, Frequency: 1
# Token: اقت, Frequency: 1
# Token: ابھرتے, Frequency: 1
# Token: Ka, Frequency: 1
# Token: ترو, Frequency: 1
# Token: بائیٹ, Frequency: 1
# Token: بھرنا, Frequency: 1
# Token: خامشی, Frequency: 1
# Token: آمــــین, Frequency: 1
# Token: 2تو, Frequency: 1
# Token: جالے, Frequency: 1
# Token: ٹکہ, Frequency: 1
# Token: لاری, Frequency: 1
# Token: ھولندی, Frequency: 1
# Token: فرانک, Frequency: 1
# Token: مارتیز, Frequency: 1
# Token: موریس, Frequency: 1
# Token: ھنری, Frequency: 1
# Token: چچازاد, Frequency: 1
# Token: مورل, Frequency: 1
# Token: فیس_گھٹاۇ_گرانٹ_, Frequency: 1
# Token: Syeda, Frequency: 1
# Token: لیجانے, Frequency: 1
# Token: مرزئی, Frequency: 1
# Token: سبکرائبر, Frequency: 1
# Token: ڈسکشن, Frequency: 1
# Token: تکر, Frequency: 1
# Token: بونگا, Frequency: 1
# Token: توجیل, Frequency: 1

# %% [markdown]
# # 2. Tf-IDF (Term Frequency-Inverse Document Frequency):
# o Apply the Tf-IDF algorithm to extract relevant terms from the dataset. Identify
# the most important terms contributing to sentiment in Urdu text.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

file_path = 'lemmatized_urdu.csv'  
df = pd.read_csv(file_path, encoding='utf-8')

first_column = df.columns[0]

df[first_column] = df[first_column].apply(lambda x: ' '.join(str(x).split()))  

vectorizer = TfidfVectorizer()

tfidf_matrix = vectorizer.fit_transform(df[first_column])

terms = vectorizer.get_feature_names_out()  
tfidf_scores = tfidf_matrix.toarray()  

average_tfidf_scores = tfidf_scores.mean(axis=0)

tfidf_dict = dict(zip(terms, average_tfidf_scores))

sorted_tfidf = sorted(tfidf_dict.items(), key=lambda x: x[1], reverse=True)

print("\nTop Terms Contributing to Sentiment (Based on TF-IDF):")
for term, score in sorted_tfidf[:10]:  
    print(f"Term: {term}, TF-IDF Score: {score}")
# Out:
# Top Terms Contributing to Sentiment (Based on TF-IDF):
# Term: میں, TF-IDF Score: 0.032466776861929114
# Term: کو, TF-IDF Score: 0.026662202116034036
# Term: کر, TF-IDF Score: 0.026494329594945538
# Term: سے, TF-IDF Score: 0.026292160665067003
# Term: نہیں, TF-IDF Score: 0.025317272675427615
# Term: کا, TF-IDF Score: 0.02416601795096775
# Term: بھی, TF-IDF Score: 0.02256890342295227
# Term: نے, TF-IDF Score: 0.02030662988915006
# Term: آپ, TF-IDF Score: 0.015229593666332194
# Term: اس, TF-IDF Score: 0.013776788556752777

# %% [markdown]
# # Word2Vec:
# o Train a Word2Vec model on your dataset to capture the relationship between Urdu
# words based on context.
# o Deliverable: List the top 5 words most similar to the word &quot;اچھا&quot; (good) using the
# trained model.

# %%
import gensim
from gensim.models import Word2Vec

file_path = 'lemmatized_urdu.csv'  
df = pd.read_csv(file_path, encoding='utf-8')

first_column = df.columns[0]

tokenized_corpus = [str(text).split() for text in df[first_column]]

# Step 2: Train the Word2Vec model using the Skip-Gram approach (sg=1)
word2vec_model = Word2Vec(
    sentences=tokenized_corpus,  # Tokenized corpus
    vector_size=200,             # Increase the dimensionality of word vectors to capture more context
    window=4,                    # Context window size
    sg=1,                        # Skip-Gram (sg=1), use CBOW if sg=0
    min_count=5,                 # Exclude rare words (set a higher minimum count to remove noise)
    workers=4                    # Train for more epochs to allow the model to learn better
)

def find_similar_words(word, topn=5):
    try:
        similar_words = word2vec_model.wv.most_similar(word, topn=topn)
        print(f"\nTop {topn} words most similar to '{word}':")
        for similar_word, similarity in similar_words:
            print(f"Word: {similar_word}, Similarity: {similarity}")
    except KeyError:
        print(f"The word '{word}' is not in the vocabulary.")

# Example usage: Find the top 5 words similar to "اچھا"
find_similar_words("اچھا")
# Out:
# Top 5 words most similar to 'اچھا':
# Word: شعر, Similarity: 0.8171318173408508
# Word: بتانا, Similarity: 0.80801922082901
# Word: پسند, Similarity: 0.8040664196014404
# Word: حال, Similarity: 0.8029041290283203
# Word: کتنا, Similarity: 0.8017340302467346

# %% [markdown]
# # Phase 4: N-grams Analysis
# 1. Unigram, Bigram, and Trigram Analysis:
# o Create unigrams, bigrams, and trigrams from the dataset of Urdu text.
# o Deliverable: List the top 10 most common bigrams and trigrams in the dataset,
# along with their frequencies.
# o Challenges to Address: Proper tokenization for Urdu to avoid breaking the
# words incorrectly (due to right-to-left script).

# %%
#######################################    UNI-GRAM   #################################
from collections import Counter

file_path = 'lemmatized_urdu.csv'  
df = pd.read_csv(file_path, encoding='utf-8')

first_column = df.columns[0]

all_unigrams = []

for text in df[first_column]:
    tokens = str(text).split()  
    all_unigrams.extend(tokens)  

unigram_frequency = Counter(all_unigrams)

sorted_unigrams = sorted(unigram_frequency.items(), key=lambda x: x[1], reverse=True)

print("\nTop 10 Most Frequent Unigrams:")
for unigram, freq in sorted_unigrams[:10]:
    print(f"Unigram: {unigram}, Frequency: {freq}")
# Out:
# Top 10 Most Frequent Unigrams:
# Unigram: میں, Frequency: 7323
# Unigram: کو, Frequency: 5640
# Unigram: سے, Frequency: 5471
# Unigram: کر, Frequency: 5252
# Unigram: کا, Frequency: 4966
# Unigram: نہیں, Frequency: 4445
# Unigram: بھی, Frequency: 3890
# Unigram: نے, Frequency: 3711
# Unigram: اس, Frequency: 2161
# Unigram: آپ, Frequency: 2105

# %%
###############################################   BI GRAMS   ################################


from collections import Counter
from nltk import ngrams  

file_path = 'lemmatized_urdu.csv'  
df = pd.read_csv(file_path, encoding='utf-8')

first_column = df.columns[0]

all_bigrams = []

for text in df[first_column]:
    tokens = str(text).split()  # Tokenize the text into unigrams
    bigrams = list(ngrams(tokens, 2))  # Generate bigrams (n=2)
    all_bigrams.extend(bigrams)  # Add the bigrams to the list

bigram_frequency = Counter(all_bigrams)

sorted_bigrams = sorted(bigram_frequency.items(), key=lambda x: x[1], reverse=True)

print("\nTop 10 Most Frequent Bigrams:")
for bigram, freq in sorted_bigrams[:10]:
    print(f"Bigram: {bigram}, Frequency: {freq}")
# Out:
# Top 10 Most Frequent Bigrams:
# Bigram: ('عمران', 'خان'), Frequency: 503
# Bigram: ('نواز', 'شریف'), Frequency: 449
# Bigram: ('t', 'co'), Frequency: 407
# Bigram: ('میں', 'نے'), Frequency: 350
# Bigram: ('آپ', 'کو'), Frequency: 314
# Bigram: ('سندھ', 'پولیس'), Frequency: 296
# Bigram: ('بھی', 'نہیں'), Frequency: 252
# Bigram: ('آرمی', 'چیف'), Frequency: 224
# Bigram: ('آپ', 'نے'), Frequency: 222
# Bigram: ('میں', 'بھی'), Frequency: 213

# %%
##################################################  TRI GRAMS   ###########################################


from collections import Counter
from nltk import ngrams  

file_path = 'lemmatized_urdu.csv'  
df = pd.read_csv(file_path, encoding='utf-8')

first_column = df.columns[0]

all_trigrams = []

for text in df[first_column]:
    tokens = str(text).split()  # Tokenize the text into unigrams
    trigrams = list(ngrams(tokens, 3))  # Generate trigrams (n=3)
    all_trigrams.extend(trigrams)  # Add the trigrams to the list

trigram_frequency = Counter(all_trigrams)

sorted_trigrams = sorted(trigram_frequency.items(), key=lambda x: x[1], reverse=True)

print("\nTop 10 Most Frequent Trigrams:")
for trigram, freq in sorted_trigrams[:10]:
    print(f"Trigram: {trigram}, Frequency: {freq}")
# Out:
# Top 10 Most Frequent Trigrams:
# Trigram: ('صلی', 'اللہ', 'علیہ'), Frequency: 90
# Trigram: ('پی', 'ڈی', 'ایم'), Frequency: 88
# Trigram: ('ووٹ', 'کو', 'عزت'), Frequency: 76
# Trigram: ('علیہ', 'وآلہ', 'وسلم'), Frequency: 75
# Trigram: ('اللہ', 'علیہ', 'وآلہ'), Frequency: 74
# Trigram: ('جزاک', 'اللہ', 'خیر'), Frequency: 73
# Trigram: ('عمران', 'خان', 'نے'), Frequency: 69
# Trigram: ('والوں', 'کو', 'فالو'), Frequency: 68
# Trigram: ('فالو', 'فالو', 'بیک'), Frequency: 67
# Trigram: ('نے', 'جواب', 'دیا'), Frequency: 64

# %% [markdown]
# # Phase 5: Sentiment Classification Model
# 1. Model Building:
# o Using the features extracted (from Tf-IDF or Word2Vec), build a machine
# learning model (e.g., Logistic Regression, SVM, or Naive Bayes) to classify the
# sentiment of the Urdu posts.
# o Deliverable: Show the accuracy, precision, recall, and F1-score of your sentiment
# classifier using a test set of Urdu text.

# %%
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report

label_column = 'is_sarcastic'  
y = df[label_column] 

X_train, X_test, y_train, y_test = train_test_split(tfidf_matrix, y, test_size=0.2, random_state=42)

naive_bayes_model = MultinomialNB()
naive_bayes_model.fit(X_train, y_train)

y_pred = naive_bayes_model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')

print("\nModel Performance Metrics (Naive Bayes - Sentiment Classification):")
print(f"Accuracy: {accuracy:.2f}")
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1-Score: {f1:.2f}")

print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Model Performance Metrics (Naive Bayes - Sentiment Classification):
# Accuracy: 0.77
# Precision: 0.78
# Recall: 0.77
# F1-Score: 0.76
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.61      0.71      1777
#          1.0       0.72      0.91      0.80      2006
#
#     accuracy                           0.77      3783
#    macro avg       0.79      0.76      0.76      3783
# weighted avg       0.78      0.77      0.76      3783

# %% [markdown]
# # Phase 6: Evaluation &amp; Optimization
# 1. Evaluation:
# o Evaluate the model&#39;s performance on a validation set of Urdu posts. Analyze
# where the model performs well and where it struggles (e.g., understanding
# complex sentences or detecting sarcasm).
# o Deliverable: Present evaluation metrics and discuss areas where improvements
# can be made.

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report

file_path = 'lemmatized_urdu.csv'  
df = pd.read_csv(file_path, encoding='utf-8')

first_column = df.columns[0]  

def urdu_tokenizer(text):
    tokens = text.split() 
    unique_tokens = list(set(tokens))  
    return unique_tokens

df['tokenized_text'] = df[first_column].apply(lambda x: ' '.join(urdu_tokenizer(str(x))))

vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(df['tokenized_text'])

unseen_posts = [
    "آپ واقعی بہت زبردست ہیں۔",  
    "یہ دن تو بہت ہی شاندار گزرا!",  
    "مجھے تمہاری مدد کی بالکل بھی ضرورت نہیں۔",  
    "میں نے زندگی میں اتنی اچھی فلم پہلے کبھی نہیں دیکھی!",  
    "یہ واقعی ایک بہت اچھا فیصلہ تھا۔"
]

unseen_tokenized = [' '.join(urdu_tokenizer(text)) for text in unseen_posts]

unseen_tfidf = vectorizer.transform(unseen_tokenized)

X_train = tfidf_matrix
y_train = df['is_sarcastic']  

model = LogisticRegression(max_iter=1000)
model.fit(X_train, y_train)

y_pred_unseen = model.predict(unseen_tfidf)

true_labels = [0, 0, 0, 1, 0]  

# Calculate evaluation metrics
accuracy = accuracy_score(true_labels, y_pred_unseen)
precision = precision_score(true_labels, y_pred_unseen, average='weighted')
recall = recall_score(true_labels, y_pred_unseen, average='weighted')
f1 = f1_score(true_labels, y_pred_unseen, average='weighted')

# Print evaluation metrics
print("Classification Report:\n", classification_report(true_labels, y_pred_unseen))
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-Score: {f1:.4f}")
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.80      1.00      0.89         4
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.80         5
#    macro avg       0.40      0.50      0.44         5
# weighted avg       0.64      0.80      0.71         5
#
# Accuracy: 0.8000
# Precision: 0.6400
# Recall: 0.8000
# F1-Score: 0.7111
# c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
